# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
species_final = pd.read_csv("species_final.csv")
species_final
# Out:
#                     taxon              type  \
# 0        Saguinus oedipus  New World monkey
# 1       Pseudoeurycea rex        Salamander
# 2    Oedipodrilus oedipus    Segmented worm
# 3       Amblytylus peitho          Leaf bug
# 4      Atomophora astraia          Leaf bug
# ..                    ...               ...
# 837   Urostephanus balrog          Milkvine
# 838  Meoneura hobbitoides               Fly
# 839        Borophagus orc     Fossil mammal
# 840      Pycnophyes smaug        Kinorhynch
# 841        Meoneura yodai               Fly
#
#                                               namesake  year_wiki  \
# 0                                          Oedipus Rex     1758.0
# 1                                          Oedipus Rex     1921.0
# 2                                          Oedipus Rex     1967.0
# 3                                               Peitho     1997.0
# 4                                         Dike/Astraea     1997.0
# ...

# %%
species_final['rank'].value_counts()
# Out:
# rank
# SPECIES       670
# GENUS         166
# KINGDOM         3
# PHYLUM          1
# FAMILY          1
# SUBSPECIES      1
# Name: count, dtype: int64

# %%
species_final[species_final['year_match'] == False]
# Out:
#                       taxon            type  \
# 22       Syntelia sunwukong          Beetle
# 23       Salassa sunwukongi            Moth
# 25           Ambulyx wukong            Moth
# 48    Salticus lilliputanus  Jumping spider
# 50                   Laputa        Filefish
# ..                      ...             ...
# 804    Mesobiotus mandalori      Tardigrade
# 824      Euronecturus grogu      Salamander
# 825    Epicratinus temuerai          Spider
# 827  Pheidole harrisonfordi             Ant
# 832   Albicetus oxymycterus   Toothed whale
#
#                                               namesake  year_wiki  \
# 22                                          Sun Wukong     2021.0
# 23                                          Sun Wukong     2023.0
# 25                                          Sun Wukong     2025.0
# 48                                            Lilliput     1846.0
# 50                                              Laputa     1930.0
# ...

# %%
#For all the years that match between year_wiki and year_gbif, filling those in in final year. For the years that don't match, taking gbif_year. The remaining ones are filled in using year_wiki, manually cross-checked using Catalogue of Life. 
species_final['final_year'] = species_final.apply(lambda row: row['year_wiki'] if row['year_match'] == True else row['year_gbif'],axis=1)

# %%
species_final[species_final['final_year'].isna()]
# Out:
#                       taxon       type  \
# 24     Brevistoma raksasiae  Spoonwing
# 52   Blossfeldia liliputana     Cactus
# 54   Dryadella lilliputiana     Orchid
# 58        Viola lilliputana     Violet
# 62     Pluteus liliputianus   Mushroom
# ..                      ...        ...
# 787       Bathynomus vaderi     Isopod
# 806        Begonia amidalae    Begonia
# 812        Tetramorium jedi        Ant
# 834      Urostephanus lokii   Milkvine
# 837     Urostephanus balrog   Milkvine
#
#                                               namesake  year_wiki  \
# 24                                   Princess Iron Fan     2025.0
# 52                                            Lilliput     1937.0
# 54                                            Lilliput     1978.0
# 58                                            Lilliput     2012.0
# 62                                            Lilliput     2019.0
# ..                                                 ...        ...
# ...

# %%
species_final['final_year'] = species_final['final_year'].fillna(species_final['year_wiki'])

# %%
species_final[species_final['final_year'].isna()]
# Out:
#                       taxon          type  \
# 64     Matelea lilliputiana      Milkvine
# 275         Solanum watneyi   Bush tomato
# 585   Macrocarpaea apparata  Gentianaceae
# 692   Peperomia hobbitoides    Piperaceae
# 782  Begonia darthvaderiana       Begonia
# 806        Begonia amidalae       Begonia
# 834      Urostephanus lokii      Milkvine
# 837     Urostephanus balrog      Milkvine
#
#                                               namesake  year_wiki  \
# 64                                            Lilliput        NaN
# 275                            Mark Watney,The Martian        NaN
# 585                                         Apparating        NaN
# 692                                            Hobbits        NaN
# 782  "The epithet refers to the resemblance of the ...        NaN
# 806  "With embellished silvery spots on dark sheen ...        NaN
# 834                                               Loki        NaN
# ...

# %%
# Manually filling the few NaN values in final_year using Catalogue of Life
species_final.loc[species_final['taxon'] == 'Matelea lilliputiana', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Solanum watneyi', 'final_year'] = 2016
species_final.loc[species_final['taxon'] == 'Macrocarpaea apparata', 'final_year'] = 2003
species_final.loc[species_final['taxon'] == 'Peperomia hobbitoides', 'final_year'] = 2003
species_final.loc[species_final['taxon'] == 'Begonia darthvaderiana', 'final_year'] = 2014
species_final.loc[species_final['taxon'] == 'Begonia amidalae', 'final_year'] = 2014
species_final.loc[species_final['taxon'] == 'Urostephanus lokii', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Urostephanus balrog', 'final_year'] = 2024

# %%
species_final['final_year'].isna().sum()
# Out:
# np.int64(0)

# %%
only_genus = species_final[species_final['rank'] == 'GENUS']
only_genus.to_csv("only_genus.csv", index=False)

# %%
only_genus
# Out:
#                     taxon                type  \
# 13           Gargantuavis                Bird
# 16          Wukongopterus           Pterosaur
# 23     Salassa sunwukongi                Moth
# 25         Ambulyx wukong                Moth
# 26                Sycorax                 Fly
# ..                    ...                 ...
# 800      Epicratinus luke              Spider
# 804  Mesobiotus mandalori          Tardigrade
# 815              Ackbaria            True bug
# 818           Stormtropis  Baldlegged spiders
# 825  Epicratinus temuerai              Spider
#
#                                               namesake  year_wiki  \
# 13                                           Gargantua     1998.0
# 16                                          Sun Wukong     2009.0
# 23                                          Sun Wukong     2023.0
# 25                                          Sun Wukong     2025.0
# 26                                 Sycorax,The Tempest     1839.0
# ...

# %%
#Some of these are ranked 'Genus' because GBIF was not able to match it to a species name in the backbone taxonomy database and could only match it to genus. Manually checking the one that are species names but ranked as genus with Catalogue of Life database.  
#many of them also have their years recorded according to Genus. Changing that too. 
species_final.loc[species_final['taxon'] == 'Matelea lilliputiana', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Matelea lilliputiana', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus temuerai', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus luke', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus luke', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus luke', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus leia', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus leia', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus yoda', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus yoda', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Unicauda fimbrethilae', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus smeagol', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus smeagol', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Idiopyrgus meriadoci', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Idiopyrgus meriadoci', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Idiopyrgus meriadoci', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Idiopyrgus eowynae', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Idiopyrgus eowynae', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Spaeleoleptes gimli', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Spaeleoleptes gimli', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Leptanilla voldemort', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Leptanilla voldemort', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus raiden', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus raiden', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus baraka', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus baraka', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Otacilia khezu', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Otacilia khezu', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Orcevia bokoblin', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Orcevia bokoblin', 'final_year'] = 2023
species_final.loc[species_final['taxon'] == 'Orcevia yahaha', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Orcevia yahaha', 'final_year'] = 2023
species_final.loc[species_final['taxon'] == 'Acmopolynema isaura', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Acmopolynema isaura', 'final_year'] = 2007
species_final.loc[species_final['taxon'] == 'Xizangiana plankton', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Xizangiana plankton', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Agroecotettix idic', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Agroecotettix idic', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Troglocoelotes doul', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Troglocoelotes doul', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Epicratinus arlequina', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Epicratinus arlequina', 'final_year'] = 2024
species_final.loc[species_final['taxon'] == 'Bensonella dracula', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Bensonella dracula', 'final_year'] = 2025
species_final.loc[species_final['taxon'] == 'Monodelphis pinocchio', 'rank'] = 'SPECIES'
species_final.loc[species_final['taxon'] == 'Monodelphis pinocchio', 'final_year'] = 2015

# %%
#Dropping the ones that have no entry on Catalogue of Life either. 
to_drop = ['Mesobiotus mandalori', 'Acledra nazgul', 'Chiloglanis frodobagginsi', 'Lotharingius frodoi', 'Marjumia bagginsi', 'Myloplus sauron', 'Martesia tolkieni', 'Euconnus hosakae', 'Nocticola pheromosa', 'Hemipeplus heisenbergi', 'Hemipeplus saymyname', 'Rotundicardia mariobrosorum', 'Geragnostus waldorfstatleri', 'Boophis burnhamae', 'Boophis pikei', 'Boophis archeri', 'Boophis janewayae', 'Boophis siskoi', 'Boophis picardi', 'Boophis kirki', 'Branchiostegus sanae', 'Chloridops regiskongi', 'Goniomonas avonlea', 'Millerocaulis tekelili', 'Aleiodes dresdeni', 'Ophiodon ozymandias', 'Laelius starki', 'Laelius tullyi', 'Laelius targaryeni', 'Laelius martelli', 'Laelius lannisteri', 'Laelius baratheoni', 'Laelius arryni', 'Aleiodes teatimei', 'Aleiodes downeyi', 'Aleiodes conina', 'Torreyites detriti', 'Phoenicopsis rincewindii', 'Ginkgoites garlickianus', 'Ginkgoites nannyoggiae', 'Ginkgoites weatherwaxiae', 'Czekanowskia anguae', 'Plebejus fyodor', 'Plebejus pilgram', 'Plebejus ardis', 'Pseudolucia zina', 'Pseudolucia humbert', 'Nabokovia ada', 'Paralycaeides shade', 'Itylos pnin', 'Pseudolucia zembla', 'Pseudolucia hazeorum', 'Pseudolucia clarea', 'Fujuriphyes cthulhu', 'Millerocaulis tekelili', 'Hemignathus vorpalis', 'Thaleops mobydicki', 'Paracardiophorus liliputanus', 'Salticus lilliputanus', 'Ambulyx wukong', 'Salassa sunwukongi']

# %%
species_final = species_final[~species_final['taxon'].isin(to_drop)]

# %%
species_final.shape
# Out:
# (780, 27)

# %%
species_final['rank'].value_counts()
# Out:
# rank
# SPECIES       693
# GENUS          81
# KINGDOM         3
# PHYLUM          1
# FAMILY          1
# SUBSPECIES      1
# Name: count, dtype: int64

# %%
#Only keeping species and genus for this analysis. 
species_final = species_final[species_final['rank'].isin(['SPECIES', 'GENUS'])]

# %%
species_final['rank'].value_counts()
# Out:
# rank
# SPECIES    693
# GENUS       81
# Name: count, dtype: int64

# %%
species_final = species_final.drop(columns = ['year_wiki', 'named_by_wiki', 'year_gbif', 'year_match'])

# %%
species_final = species_final.drop(columns = ['named_by_clean_wiki', 'authorship'])

# %%
species_final
# Out:
#                     taxon              type  \
# 0        Saguinus oedipus  New World monkey
# 1       Pseudoeurycea rex        Salamander
# 2    Oedipodrilus oedipus    Segmented worm
# 3       Amblytylus peitho          Leaf bug
# 4      Atomophora astraia          Leaf bug
# ..                    ...               ...
# 837   Urostephanus balrog          Milkvine
# 838  Meoneura hobbitoides               Fly
# 839        Borophagus orc     Fossil mammal
# 840      Pycnophyes smaug        Kinorhynch
# 841        Meoneura yodai               Fly
#
#                                               namesake fictional_universe  \
# 0                                          Oedipus Rex    Greek mythology
# 1                                          Oedipus Rex    Greek mythology
# 2                                          Oedipus Rex    Greek mythology
# 3                                               Peitho    Greek mythology
# ...

# %% [markdown]
# # Analysis

# %%
species_final['final_year'].value_counts().sort_index().reset_index()
# Out:
#     final_year  count
# 0       1758.0      2
# 1       1839.0      1
# 2       1876.0      1
# 3       1896.0      4
# 4       1900.0      1
# ..         ...    ...
# 66      2021.0     52
# 67      2022.0     22
# 68      2023.0     17
# 69      2024.0     18
# 70      2025.0      1
#
# [71 rows x 2 columns]

# %%
species_final['fictional_universe'].value_counts().head(10)
# Out:
# fictional_universe
# Tolkien                   184
# Star Wars                  55
# Other literature           44
# Discworld                  37
# Other films                20
# Victor Hugo                19
# Harry Potter               19
# A Song of Ice and Fire     17
# Marvel Comics              16
# William Shakespeare        16
# Name: count, dtype: int64

# %%
species_final['taxon'] = species_final['taxon'].str.strip()
species_final['canonicalName'] = species_final['canonicalName'].str.strip()
species_final['type'] = species_final['type'].str.strip()
species_final['fictional_universe'] = species_final['fictional_universe'].str.strip()
species_final['character_type'] = species_final['character_type'].str.strip()
species_final['species_gbif'] = species_final['species_gbif'].str.strip()

# %%
species_final.replace('', pd.NA, inplace=True)

# %%
species_final['character_type'].value_counts()
# Out:
# character_type
# Hobbits                                       38
# Ainur                                         28
# Elves                                         24
# Race of Men                                   19
# Objects and locations                         19
# Animals                                       18
# Named after other characters and elements     15
# Named after Darth Vader                       13
# Dwarves                                       12
# Named after magical creatures                  9
# Named after Yoda                               7
# Elvish words                                   7
# Named after wizards                            7
# J. R. R. Tolkien                               6
# The Nazgûl                                     5
# Named afterStar Warsactors                     5
# Other characters                               4
# Named after Chewbacca                          4
# Named after Luke Skywalker                     4
# ...

# %%
#Removing species named after Tolkien and Star Wars actors, and only keeping those named after fictional works.

# %%
species_final[species_final['character_type'] == 'J. R. R. Tolkien']
# Out:
#                     taxon       type          namesake fictional_universe  \
# 589    Leucothoe tolkieni   Amphipod  J. R. R. Tolkien            Tolkien
# 590      Gabrius tolkieni     Beetle  J. R. R. Tolkien            Tolkien
# 591             Tolkienia  Trilobite  J. R. R. Tolkien            Tolkien
# 592  Shireplitis tolkieni       Wasp  J. R. R. Tolkien            Tolkien
# 593  Drassodella tolkieni     Spider  J. R. R. Tolkien            Tolkien
# 594  Hyloscirtus tolkieni       Frog  J. R. R. Tolkien            Tolkien
#
#        character_type  media_type  \
# 589  J. R. R. Tolkien  Literature
# 590  J. R. R. Tolkien  Literature
# 591  J. R. R. Tolkien  Literature
# 592  J. R. R. Tolkien  Literature
# 593  J. R. R. Tolkien  Literature
# 594  J. R. R. Tolkien  Literature
#
#                                             notes_wiki   kingdom      phylum  \
# 589                                                NaN  Animalia  Arthropoda
# ...

# %%
species_final[species_final['character_type'] == 'Named afterStar Warsactors']
# Out:
#                        taxon    type                         namesake  \
# 825     Epicratinus temuerai  Spider                 Temuera Morrison
# 826   Calponia harrisonfordi  Spider                    Harrison Ford
# 827   Pheidole harrisonfordi     Ant                    Harrison Ford
# 828  Cantharis mikkelsenorum  Beetle  Lars MikkelsenandMads Mikkelsen
# 829         Ctenus monaghani  Spider                 Dominic Monaghan
#
#     fictional_universe              character_type media_type  \
# 825          Star Wars  Named afterStar Warsactors      Films
# 826          Star Wars  Named afterStar Warsactors      Films
# 827          Star Wars  Named afterStar Warsactors      Films
# 828          Star Wars  Named afterStar Warsactors      Films
# 829          Star Wars  Named afterStar Warsactors      Films
#
#                                             notes_wiki   kingdom      phylum  \
# 825  The specific epithet, temuerai, is a patronym ...  Animalia  Arthropoda
# ...

# %%
to_drop = ['Leucothoe tolkieni', 'Gabrius tolkieni', 'Tolkienia', 'Shireplitis tolkieni', 'Drassodella tolkieni', 'Hyloscirtus tolkieni', 'Epicratinus temuerai', 'Calponia harrisonfordi', 'Pheidole harrisonfordi', 'Cantharis mikkelsenorum','Ctenus monaghani']

# %%
species_cleaned = species_final[~species_final['taxon'].isin(to_drop)]

# %% [markdown]
# ## Total number of taxa in this dataset?

# %%
len(species_cleaned)
# Out:
# 763

# %% [markdown]
# ## Breakup by species and genera

# %%
species_cleaned['rank'].value_counts()
# Out:
# rank
# SPECIES    683
# GENUS       80
# Name: count, dtype: int64

# %% [markdown]
# ## Timeline of species named after fictional works

# %%
species_cleaned['final_year'].value_counts().sort_index().plot(kind='line',marker='o',figsize=(12,5),title='Timeline of Species Named After Fictional Characters')
# Out:
# <Axes: title={'center': 'Timeline of Species Named After Fictional Characters'}, xlabel='final_year'>

# %%
#Saving as csv to plot in Flourish
year_counts = species_cleaned['final_year'].value_counts().sort_index().reset_index()
year_counts.columns = ['year', 'count']
year_counts.to_csv("year_plot.csv", index = False)

# %%
species_cleaned['final_year'].value_counts().sort_index().reset_index()
# Out:
#     final_year  count
# 0       1758.0      2
# 1       1839.0      1
# 2       1876.0      1
# 3       1896.0      4
# 4       1900.0      1
# ..         ...    ...
# 66      2021.0     52
# 67      2022.0     22
# 68      2023.0     16
# 69      2024.0     18
# 70      2025.0      1
#
# [71 rows x 2 columns]

# %%
species_cleaned[species_cleaned['final_year'] == 2019]['fictional_universe'].value_counts()
# Out:
# fictional_universe
# Tolkien                        8
# Star Wars                      7
# Ready Player One               6
# Other literature               5
# Greek mythology                4
# Marvel Comics                  3
# William Shakespeare            3
# Asterix                        3
# Gulliver's Travels             2
# Popeye                         2
# Other television series        2
# The Witcher                    2
# Jorge Amado                    1
# Doctor Who                     1
# Pokémon                        1
# Galaga                         1
# Star Trek                      1
# Godzilla                       1
# Other films                    1
# Avatar                         1
# Other comics                   1
# The Adventures of Pinocchio    1
# H. P. Lovecraft                1
# A Song of Ice and Fire         1
# The Smurfs                     1
# Name: count, dtype: int64

# %%
species_cleaned[species_cleaned['final_year'] == 2012]['fictional_universe'].value_counts()
# Out:
# fictional_universe
# Discworld                      30
# Predator                       15
# Other literature                7
# Tolkien                         4
# Star Wars                       3
# Gulliver's Travels              1
# Victor Hugo                     1
# Moby-Dick                       1
# The Adventures of Pinocchio     1
# DC Comics                       1
# Looney Tunes                    1
# Star Trek                       1
# The Big Bang Theory             1
# Harry Potter                    1
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution by media_type

# %%
species_cleaned[species_cleaned['media_type'] == 'Other media']
# Out:
#                   taxon    type                                 namesake  \
# 568  Orsonwelles bellum  Spider  The War of the Worlds(1938 radio drama)
#
#     fictional_universe character_type   media_type  \
# 568                NaN            NaN  Other media
#
#                                             notes_wiki   kingdom      phylum  \
# 568  "This species, collected below the radio tower...  Animalia  Arthropoda
#
#          class  ...       family        genus        species_gbif  \
# 568  Arachnida  ...  Linyphiidae  Orsonwelles  Orsonwelles bellum
#
#                        scientificName       canonicalName     rank    status  \
# 568  Orsonwelles bellum Hormiga, 2002  Orsonwelles bellum  SPECIES  ACCEPTED
#
#     extinct  author_gbif final_year
# 568   False      Hormiga     2002.0
#
# [1 rows x 21 columns]

# %%
species_cleaned.loc[species_cleaned['taxon'] == 'Orsonwelles bellum', 'fictional_universe'] = 'The War of the Worlds'
species_cleaned.loc[species_cleaned['taxon'] == 'Orsonwelles bellum', 'media_type'] = 'Radio'

# %%
species_cleaned['media_type'].value_counts().sort_values(ascending = True).plot(kind = 'barh')
# Out:
# <Axes: ylabel='media_type'>

# %%
media_rank_counts = (species_cleaned.groupby(['media_type', 'rank']).size().reset_index(name='count'))
media_rank_counts
# Out:
#     media_type     rank  count
# 0       Comics    GENUS      4
# 1       Comics  SPECIES     66
# 2        Films    GENUS     12
# 3        Films  SPECIES    128
# 4        Games    GENUS      3
# 5        Games  SPECIES     36
# 6   Literature    GENUS     56
# 7   Literature  SPECIES    403
# 8        Radio  SPECIES      1
# 9   Television    GENUS      5
# 10  Television  SPECIES     49

# %%
pivoted = media_rank_counts.pivot(index='media_type', columns='rank', values='count').fillna(0).reset_index()
pivoted
# Out:
# rank  media_type  GENUS  SPECIES
# 0         Comics    4.0     66.0
# 1          Films   12.0    128.0
# 2          Games    3.0     36.0
# 3     Literature   56.0    403.0
# 4          Radio    0.0      1.0
# 5     Television    5.0     49.0

# %%
species_cleaned['media_type'].value_counts().reset_index()
# Out:
#    media_type  count
# 0  Literature    459
# 1       Films    140
# 2      Comics     70
# 3  Television     54
# 4       Games     39
# 5       Radio      1

# %% [markdown]
# ## How many are extinct in this dataset?

# %%
species_cleaned['extinct'].value_counts()
# Out:
# extinct
# False    677
# True      86
# Name: count, dtype: int64

# %% [markdown]
# ## Top 10 fictional works that dominate species naming?

# %%
species_cleaned['fictional_universe'].value_counts().head(10).reset_index()
#Clean this out - other literature means nothing - add the names of the literature of films to jkeep this clean and get an actual count.
# Out:
#        fictional_universe  count
# 0                 Tolkien    178
# 1               Star Wars     50
# 2        Other literature     44
# 3               Discworld     37
# 4             Other films     20
# 5             Victor Hugo     19
# 6            Harry Potter     19
# 7  A Song of Ice and Fire     17
# 8           Marvel Comics     16
# 9     William Shakespeare     16

# %%
#Replacing 'other films' and 'other literature' with the names of the various works. Not splitting on the comma since some entries don't have a comma separating namesake and fictional work.
species_cleaned.loc[species_cleaned['taxon'] == 'Eubetia boop', 'fictional_universe'] = 'Betty Boop'
species_cleaned.loc[species_cleaned['taxon'] == 'Sinemys gamera', 'fictional_universe'] = 'Gamera'
species_cleaned.loc[species_cleaned['taxon'] == 'Teratohyla amelie', 'fictional_universe'] = 'Amélie'
species_cleaned.loc[species_cleaned['taxon'] == 'Tithaeus drac', 'fictional_universe'] = 'Enemy Mine'
species_cleaned.loc[species_cleaned['taxon'] == 'Eoperipatus totoro', 'fictional_universe'] = 'My Neighbour Totoro'
species_cleaned.loc[species_cleaned['taxon'] == 'Cystomastacoides kiddo', 'fictional_universe'] = 'Kill Bill'
species_cleaned.loc[species_cleaned['taxon'] == 'Axima sidi', 'fictional_universe'] = 'Ice Age'
species_cleaned.loc[species_cleaned['taxon'] == 'Prochyliza georgekaplani', 'fictional_universe'] = 'North by Northwest'
species_cleaned.loc[species_cleaned['taxon'] == 'Zuul crurivastator', 'fictional_universe'] = 'Ghostbusters'
species_cleaned.loc[species_cleaned['taxon'] == 'Prolatcyclus kindzadza', 'fictional_universe'] = 'Kin-dza-dza!'
species_cleaned.loc[species_cleaned['taxon'] == 'Coptoborus brigman', 'fictional_universe'] = 'The Abyss'
species_cleaned.loc[species_cleaned['taxon'] == 'Coptoborus furiosa', 'fictional_universe'] = 'Mad Max: Fury Road'
species_cleaned.loc[species_cleaned['taxon'] == 'Coptoborus trinity', 'fictional_universe'] = 'The Matrix'
species_cleaned.loc[species_cleaned['taxon'] == 'Coptoborus vrataski', 'fictional_universe'] = 'Edge of Tomorrow'
species_cleaned.loc[species_cleaned['taxon'] == 'Trigonopterus gundala', 'fictional_universe'] = 'Gundala'
species_cleaned.loc[species_cleaned['taxon'] == 'Anisotremus rambo', 'fictional_universe'] = 'Rambo: First Blood Part II'
species_cleaned.loc[species_cleaned['taxon'] == 'Proctoporus optimus', 'fictional_universe'] = 'Transformers'
species_cleaned.loc[species_cleaned['taxon'] == 'Paravima totoro', 'fictional_universe'] = 'My Neighbour Totoro'

# %%
species_cleaned[species_cleaned['fictional_universe'] == 'Other literature']
# Out:
#                                taxon                type  \
# 251                          Skierka                Rust
# 253           Paramphientomum yumyum           Barklouse
# 254                        Morlockia          Crustacean
# 255                     Agra ichabod       Ground beetle
# 256             Micropholcus evaluna       Cellar spider
# 257                          Trurlia         Rove beetle
# 258                   Calumma tarzan           Chameleon
# 259          Bokermannohyla sagarana                Frog
# 261                Auplopus charlesi                Wasp
# 262                 Dipogon marlowei                Wasp
# 263               Priocnessus vancei                Wasp
# 264          Inconnivus billibunteri              Tanaid
# 265               Oileus gasparilomi         Bess beetle
# 267                 Magelona sinbadi      Segmented worm
# 268        Ophryotrocha langstrumpae     Polychaete worm
# ...

# %%
species_cleaned.loc[species_cleaned['taxon'] == 'Paramphientomum yumyum', 'fictional_universe'] = 'The Mikado'
species_cleaned.loc[species_cleaned['taxon'] == 'Agra ichabod', 'fictional_universe'] = 'The Legend of Sleepy Hollow'
species_cleaned.loc[species_cleaned['taxon'] == 'Micropholcus evaluna', 'fictional_universe'] = '"Eva Luna" and "The Stories of Eva Luna"'
species_cleaned.loc[species_cleaned['taxon'] == 'Calumma tarzan', 'fictional_universe'] = 'Tarzan'
species_cleaned.loc[species_cleaned['taxon'] == 'Bokermannohyla sagarana', 'fictional_universe'] = 'Sagarana'
species_cleaned.loc[species_cleaned['taxon'] == 'Auplopus charlesi', 'fictional_universe'] = 'The Thin Man'
species_cleaned.loc[species_cleaned['taxon'] == 'Dipogon marlowei', 'fictional_universe'] = 'Philip Marlowe series'
species_cleaned.loc[species_cleaned['taxon'] == 'Priocnessus vancei', 'fictional_universe'] = 'Philo Vance series'
species_cleaned.loc[species_cleaned['taxon'] == 'Inconnivus billibunteri', 'fictional_universe'] = 'Billy Bunter'
species_cleaned.loc[species_cleaned['taxon'] == 'Oileus gasparilomi', 'fictional_universe'] = 'Men of Maize'
species_cleaned.loc[species_cleaned['taxon'] == 'Magelona sinbadi', 'fictional_universe'] = 'Sinbad the Sailor'
species_cleaned.loc[species_cleaned['taxon'] == 'Ophryotrocha langstrumpae', 'fictional_universe'] = 'Pippi Longstocking'
species_cleaned.loc[species_cleaned['taxon'] == 'Calochaete cimrmanii', 'fictional_universe'] = 'Jára Cimrman'
species_cleaned.loc[species_cleaned['taxon'] == 'Simlops jamesbondi', 'fictional_universe'] = 'James Bond'
species_cleaned.loc[species_cleaned['taxon'] == 'Chimerella corleone', 'fictional_universe'] = 'The Godfather'
species_cleaned.loc[species_cleaned['taxon'] == 'Hyorhinomys stuempkei', 'fictional_universe'] = 'The Snouters: Form and Life of the Rhinogrades'
species_cleaned.loc[species_cleaned['taxon'] == 'Phytotelmatrichis osopaddington', 'fictional_universe'] = 'Paddington Bear'
species_cleaned.loc[species_cleaned['taxon'] == 'Solanum watneyi', 'fictional_universe'] = 'The Martian'
species_cleaned.loc[species_cleaned['taxon'] == 'Epimeria cinderella', 'fictional_universe'] = 'Cinderella'
species_cleaned.loc[species_cleaned['taxon'] == 'Meoneura goldemari', 'fictional_universe'] = 'Goldemar'
species_cleaned.loc[species_cleaned['taxon'] == 'Meoneura nilsholgerssoni', 'fictional_universe'] = 'The Wonderful Adventures of Nils'
species_cleaned.loc[species_cleaned['taxon'] == 'Meoneura oskari', 'fictional_universe'] = 'The Tin Drum'
species_cleaned.loc[species_cleaned['taxon'] == 'Myrmecium oompaloompa', 'fictional_universe'] = 'Charlie and the Chocolate Factory'
species_cleaned.loc[species_cleaned['taxon'] == 'Ochyrocera charlotte', 'fictional_universe'] = "Charlotte's Web"
species_cleaned.loc[species_cleaned['taxon'] == 'Ochyrocera misspider', 'fictional_universe'] = 'Little Miss Spider'
species_cleaned.loc[species_cleaned['taxon'] == 'Buratina truncata', 'fictional_universe'] = 'The Adventures of Buratino'
species_cleaned.loc[species_cleaned['taxon'] == 'Meoneura mucki', 'fictional_universe'] = 'Little Muck'
species_cleaned.loc[species_cleaned['taxon'] == 'Mischocyttarus kallindusfloren', 'fictional_universe'] = 'Neverness'
species_cleaned.loc[species_cleaned['taxon'] == 'Tegenaria shirin', 'fictional_universe'] = 'Khosrow and Shirin'
species_cleaned.loc[species_cleaned['taxon'] == 'Caridina shahrazadae', 'fictional_universe'] = 'One Thousand and One Nights'
species_cleaned.loc[species_cleaned['taxon'] == 'Frenopyxis stierlitzi', 'fictional_universe'] = 'Stierlitz'
species_cleaned.loc[species_cleaned['taxon'] == 'Coptoborus katniss', 'fictional_universe'] = 'The Hunger Games'
species_cleaned.loc[species_cleaned['taxon'] == 'Pseudotanais rapunzelae', 'fictional_universe'] = 'Rapunzel'
species_cleaned.loc[species_cleaned['taxon'] == 'Gallirallus astolfoi', 'fictional_universe'] = 'Matter of France'
species_cleaned.loc[species_cleaned['taxon'] == 'Eucampesmella brascubas', 'fictional_universe'] = 'The Posthumous Memoirs of Brás Cubas'
species_cleaned.loc[species_cleaned['taxon'] == 'Eucampesmella capitu', 'fictional_universe'] = 'Dom Casmurro'
species_cleaned.loc[species_cleaned['taxon'] == 'Eucampesmella iracema', 'fictional_universe'] = 'Iracema'
species_cleaned.loc[species_cleaned['taxon'] == 'Helicina marfisae', 'fictional_universe'] = 'Marfisa'
species_cleaned.loc[species_cleaned['taxon'] == 'Axoniderma wanda', 'fictional_universe'] = 'The Host'

# %%
species_cleaned[species_cleaned['fictional_universe'].str.contains("Other")]
# Out:
#                            taxon             type  \
# 251                      Skierka             Rust
# 254                    Morlockia       Crustacean
# 257                      Trurlia      Rove beetle
# 276                  Fujuriphyes       Mud dragon
# 296               Caramuruacarus          Chigger
# 361  Sporopodiopsis mortimeriana           Lichen
# 362        Hypocaccus kidpaddlei     Clown beetle
# 363           Euathlus condorito        Tarantula
# 364                 Taito kakera       Harvestman
# 365     Nausicaamantis miyazakii           Mantis
# 366          Meoneura joedaltoni              Fly
# 367       Cigaritis syama lamuae        Butterfly
# 368               Luthela kagami           Spider
# 446                  Gamerabaena           Turtle
# 451                    Nosferatu      Cichlidfish
# 514           Savignia naniplopi           Spider
# 515       Alphomelon simpsonorum             Wasp
# 516          Acmopolynema isaura         Fairyfly
# ...

# %%
#replacing 'Other comics', 'other games' and 'other television series' 
species_cleaned.loc[species_cleaned['taxon'] == 'Sporopodiopsis mortimeriana', 'fictional_universe'] = 'Blake and Mortimer'
species_cleaned.loc[species_cleaned['taxon'] == 'Hypocaccus kidpaddlei', 'fictional_universe'] = 'Kid Paddle'
species_cleaned.loc[species_cleaned['taxon'] == 'Euathlus condorito', 'fictional_universe'] = 'Condorito'
species_cleaned.loc[species_cleaned['taxon'] == 'Taito kakera', 'fictional_universe'] = 'Inuyasha'
species_cleaned.loc[species_cleaned['taxon'] == 'Nausicaamantis miyazakii', 'fictional_universe'] = 'Nausicaä of the Valley of the Wind'
species_cleaned.loc[species_cleaned['taxon'] == 'Meoneura joedaltoni', 'fictional_universe'] = 'Lucky Luke'
species_cleaned.loc[species_cleaned['taxon'] == 'Cigaritis syama lamuae', 'fictional_universe'] = 'Urusei Yatsura'
species_cleaned.loc[species_cleaned['taxon'] == 'Luthela kagami', 'fictional_universe'] = 'Lucky Star'
species_cleaned.loc[species_cleaned['taxon'] == 'Savignia naniplopi', 'fictional_universe'] = 'Kabouter Plop'
species_cleaned.loc[species_cleaned['taxon'] == 'Alphomelon simpsonorum', 'fictional_universe'] = 'The Simpsons'
species_cleaned.loc[species_cleaned['taxon'] == 'Yochelcionella snorkorum', 'fictional_universe'] = 'Snorks'
species_cleaned.loc[species_cleaned['taxon'] == 'Odontacolus zimi', 'fictional_universe'] = 'Invader Zim'
species_cleaned.loc[species_cleaned['taxon'] == 'Lycocerus evangelium', 'fictional_universe'] = 'Neon Genesis Evangelion'
species_cleaned.loc[species_cleaned['taxon'] == 'Elthusa xena', 'fictional_universe'] = 'Xena: Warrior Princess'
species_cleaned.loc[species_cleaned['taxon'] == 'Prosopanche demogorgoni', 'fictional_universe'] = 'Stranger Things'
species_cleaned.loc[species_cleaned['taxon'] == 'Salticus lucasi', 'fictional_universe'] = 'Lucas the Spider'
species_cleaned.loc[species_cleaned['taxon'] == 'Ahaetulla farnsworthi', 'fictional_universe'] = 'Futurama'
species_cleaned.loc[species_cleaned['taxon'] == 'Coptoborus scully', 'fictional_universe'] = 'The X-Files'
species_cleaned.loc[species_cleaned['taxon'] == 'Trigonopterus unyil', 'fictional_universe'] = 'Si Unyil'
species_cleaned.loc[species_cleaned['taxon'] == 'Luthela asuka', 'fictional_universe'] = 'Neon Genesis Evangelion'
species_cleaned.loc[species_cleaned['taxon'] == 'Crash bandicoot', 'fictional_universe'] = 'Crash bandicoot'
species_cleaned.loc[species_cleaned['taxon'] == 'Halystina umberlee', 'fictional_universe'] = 'Dungeons & Dragons,Forgotten Realms'
species_cleaned.loc[species_cleaned['taxon'] == 'Taito spaceinvaders', 'fictional_universe'] = 'Space Invaders'
species_cleaned.loc[species_cleaned['taxon'] == 'Neobuthus factorio', 'fictional_universe'] = 'Factorio'
species_cleaned.loc[species_cleaned['taxon'] == 'Demyrsus digmon', 'fictional_universe'] = 'Digimon Adventure 02'
species_cleaned.loc[species_cleaned['taxon'] == 'Epicratinus mauru', 'fictional_universe'] = 'Waku Waku 7'
species_cleaned.loc[species_cleaned['taxon'] == 'Epicratinus omegarugal', 'fictional_universe'] = 'The King of Fighters'
species_cleaned.loc[species_cleaned['taxon'] == 'Emphysemastix frampt', 'fictional_universe'] = 'Dark Souls'
species_cleaned.loc[species_cleaned['taxon'] == 'Abaddon despoliator', 'fictional_universe'] = 'Warhammer 40,000'

# %%
species_cleaned[species_cleaned['fictional_universe'].str.contains("Other")]
# Out:
#                    taxon         type  \
# 251              Skierka         Rust
# 254            Morlockia   Crustacean
# 257              Trurlia  Rove beetle
# 276          Fujuriphyes   Mud dragon
# 296       Caramuruacarus      Chigger
# 446          Gamerabaena       Turtle
# 451            Nosferatu  Cichlidfish
# 516  Acmopolynema isaura     Fairyfly
# 554              Cortana    Gastropod
# 565       Otacilia khezu       Spider
# 566   Epicratinus baraka       Spider
# 567   Epicratinus raiden       Spider
#
#                                               namesake  \
# 251                                  Skierka,Balladyna
# 254                          Morlocks,The Time Machine
# 257                                 Trurl,The Cyberiad
# 276  Falkor(named Fujur in the Spanish version; the...
# 296                                           Caramuru
# 446                                             Gamera
# 451                                    Nosferatu(1922)
# ...

# %%
species_cleaned.loc[species_cleaned['taxon'] == 'Epicratinus raiden', 'fictional_universe'] = 'Mortal Kombat'
species_cleaned.loc[species_cleaned['taxon'] == 'Epicratinus baraka', 'fictional_universe'] = 'Mortal Kombat'
species_cleaned.loc[species_cleaned['taxon'] == 'Otacilia khezu', 'fictional_universe'] = 'Monster Hunter'
species_cleaned.loc[species_cleaned['taxon'] == 'Cortana', 'fictional_universe'] = 'Halo'
species_cleaned.loc[species_cleaned['taxon'] == 'Acmopolynema isaura', 'fictional_universe'] = 'Escrava Isaura'
species_cleaned.loc[species_cleaned['taxon'] == 'Nosferatu', 'fictional_universe'] = 'Nosferatu'
species_cleaned.loc[species_cleaned['taxon'] == 'Gamerabaena', 'fictional_universe'] = 'Gamera'
species_cleaned.loc[species_cleaned['taxon'] == 'Caramuruacarus', 'fictional_universe'] = 'Caramuru'
species_cleaned.loc[species_cleaned['taxon'] == 'Fujuriphyes', 'fictional_universe'] = 'The Neverending Story'
species_cleaned.loc[species_cleaned['taxon'] == 'Trurlia', 'fictional_universe'] = 'The Cyberiad'
species_cleaned.loc[species_cleaned['taxon'] == 'Morlockia', 'fictional_universe'] = 'The Time Machine'
species_cleaned.loc[species_cleaned['taxon'] == 'Skierka', 'fictional_universe'] = 'Balladyna'

# %%
species_cleaned[species_cleaned['fictional_universe'].str.contains("Other")]
# Out:
# Empty DataFrame
# Columns: [taxon, type, namesake, fictional_universe, character_type, media_type, notes_wiki, kingdom, phylum, class, order, family, genus, species_gbif, scientificName, canonicalName, rank, status, extinct, author_gbif, final_year]
# Index: []
#
# [0 rows x 21 columns]

# %%
top_universes = species_cleaned['fictional_universe'].value_counts().head(10).index
top_species = species_cleaned[species_cleaned['fictional_universe'].isin(top_universes)]
pivoted = top_species.groupby(['fictional_universe', 'rank']).size().reset_index(name='count').pivot(index='fictional_universe', columns='rank', values='count').fillna(0).reset_index()
pivoted['Total'] = pivoted[['GENUS', 'SPECIES']].sum(axis=1)
pivoted = pivoted.sort_values(by='Total', ascending=False).drop(columns='Total')

pivoted
# Out:
# rank      fictional_universe  GENUS  SPECIES
# 7                    Tolkien   25.0    153.0
# 6                  Star Wars    3.0     47.0
# 1                  Discworld    0.0     37.0
# 3               Harry Potter    1.0     18.0
# 8                Victor Hugo    1.0     18.0
# 0     A Song of Ice and Fire    4.0     13.0
# 4              Marvel Comics    1.0     15.0
# 9        William Shakespeare    5.0     11.0
# 2         Gulliver's Travels    4.0     11.0
# 5                    Pokémon    1.0     14.0

# %%
species_cleaned[species_cleaned['fictional_universe'].str.contains("Hugo")]
#18 out of 19 taxa names based on Victor Hugo's works refer to "The Hunchback of Notre-Dame."
# Out:
#                         taxon                   type  \
# 65      Paracalanus quasimodo                Copepod
# 66      Stylaclista quasimodo                   Wasp
# 67      Tetragnatha quasimodo  Long-jawed orb weaver
# 68               Agra eponine          Ground beetle
# 69        Schistura quasimodo            Stone loach
# 70     Paradynomene quasimodo                   Crab
# 71   Neopantopsalis quasimodo             Harvestman
# 72    Harpirhynchus quasimodo                   Mite
# 73             Quasimodorogas                   Wasp
# 74         Apseudes quasimodo                 Tanaid
# 75    Selenoribates quasimodo                   Mite
# 76      Chaleponcus quasimodo              Millipede
# 77    Ephemeroporus quasimodo             Water flea
# 78      Temnothorax quasimodo                    Ant
# 79          Squalus quasimodo          Dogfish shark
# 80         Epimeria quasimodo               Amphipod
# 81     Haplochromis quasimodo           Cichlid fish
# ...

# %%
species_cleaned[species_cleaned['fictional_universe'].str.contains("Tolkien")]
# Out:
#                     taxon           type             namesake  \
# 595  Macropsidius sauroni     Leafhopper               Sauron
# 596              Balrogia           Wasp              Balrogs
# 597      Mimatuta morgoth  Fossil mammal              Morgoth
# 598            Mithrandir  Fossil mammal  Gandalf(Mithrandir)
# 599   Niphredil radagasti  Fossil mammal             Radagast
# ..                    ...            ...                  ...
# 836       Litoria sauroni           Frog               Sauron
# 837   Urostephanus balrog       Milkvine              Balrogs
# 838  Meoneura hobbitoides            Fly              Hobbits
# 839        Borophagus orc  Fossil mammal                 Orcs
# 840      Pycnophyes smaug     Kinorhynch                Smaug
#
#     fictional_universe character_type  media_type  \
# 595            Tolkien          Ainur  Literature
# 596            Tolkien          Ainur  Literature
# 597            Tolkien          Ainur  Literature
# ...

# %%
species_cleaned[species_cleaned['media_type'] == "Television"]
# Out:
#                          taxon                  type  \
# 463      Yochelcionella daleki               Mollusc
# 464                Mestoronema               Mollusc
# 465          Tetramorium dalek                   Ant
# 466        Synchiropus sycorax         Dragonet fish
# 467          Cyclocardia dalek               Bivalve
# 468              Choeras zygon                  Wasp
# 469                Ophiotardis          Brittle star
# 470             Conus tribblei             Sea snail
# 471                   Agra dax         Ground beetle
# 472      Annuntidiogenes worfi           Hermit crab
# 473              Paridris gorn                  Wasp
# 474             Ledella spocki                Mussel
# 475                   Bolianus                Beetle
# 476      Synopeas klingunculum                  Wasp
# 477            Phanuromyia odo                  Wasp
# 478                    Spockia             Stink bug
# 479          Coptoborus hansen           Bark beetle
# ...

# %% [markdown]
# # Species belonging to which taxon class have most often received names inspired from fiction? (Top 10)

# %%
species_cleaned['class'].value_counts().head(10).reset_index()
#58 species don't have a class defined.
# Out:
#              class  count
# 0          Insecta    306
# 1        Arachnida    155
# 2     Malacostraca     45
# 3         Mammalia     29
# 4       Gastropoda     24
# 5         Amphibia     14
# 6    Magnoliopsida     14
# 7         Squamata     14
# 8        Diplopoda     11
# 9  Allomalorhagida     10

# %%
top_classes = species_cleaned['class'].value_counts().head(10).index
filtered = species_cleaned[species_cleaned['class'].isin(top_classes)]
grouped = filtered.groupby(['class', 'rank']).size().reset_index(name='count')
pivoted = grouped.pivot(index='class', columns='rank', values='count').fillna(0).reset_index()
pivoted['Total'] = pivoted[['GENUS', 'SPECIES']].sum(axis=1)
pivoted = pivoted.sort_values(by='Total', ascending=False).drop(columns='Total')
pivoted
# Out:
# rank            class  GENUS  SPECIES
# 5             Insecta   21.0    285.0
# 2           Arachnida    8.0    147.0
# 7        Malacostraca    4.0     41.0
# 8            Mammalia    5.0     24.0
# 4          Gastropoda    6.0     18.0
# 1            Amphibia    0.0     14.0
# 6       Magnoliopsida    0.0     14.0
# 9            Squamata    1.0     13.0
# 3           Diplopoda    0.0     11.0
# 0     Allomalorhagida    1.0      9.0

# %%
species_cleaned['class'].isna().sum()
# Out:
# np.int64(58)

# %%
species_cleaned[species_cleaned['class'].isna()]
# Out:
#                             taxon                     type  \
# 9            Medusaceratops lokii      Ceratopsiandinosaur
# 12          Gigantactis gargantua               Anglerfish
# 16                  Wukongopterus                Pterosaur
# 37                 Alfaites romeo                  Hyolith
# 44      Lohuecotitan pandafilandi               Titanosaur
# 69            Schistura quasimodo              Stone loach
# 81         Haplochromis quasimodo             Cichlid fish
# 83               Schistura aramis              Stone loach
# 84                Schistura athos              Stone loach
# 85              Schistura porthos              Stone loach
# 92          Borogovia gracilicrus         Theropoddinosaur
# 101             Eviota pinocchioi                Dwarfgoby
# 105         Irritator challengeri         Theropoddinosaur
# 111                  Garra cyrano           Log suckerfish
# 118            Danionella dracula          Ray-finned fish
# ...

# %%
species_cleaned[species_cleaned['class'] == 'Mammalia']['extinct'].value_counts()
#Most Mammalia named after fictional works are fossil mammals or extinct.
# Out:
# extinct
# True     24
# False     5
# Name: count, dtype: int64

# %%
species_cleaned['kingdom'].value_counts()
# Out:
# kingdom
# Animalia     733
# Plantae       20
# Fungi          4
# Chromista      3
# Protozoa       2
# Bacteria       1
# Name: count, dtype: int64

# %%
species_cleaned.to_csv("species_cleaned.csv", index = False)

# %% [markdown]
# # Scraping Wikipedia page for species named after fictional characters

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get("https://en.wikipedia.org/wiki/List_of_organisms_named_after_works_of_fiction")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
doc.find('h1').text
# Out:
# 'List of organisms named after works of fiction'

# %%
rows = []
current_h2 = None
current_h3 = None

for tag in doc.find_all(['h2', 'h3', 'tbody']):
    if tag.name == 'h2':
        current_h2 = tag.get_text(strip=True)
        current_h3 = None 
    elif tag.name == 'h3':
        current_h3 = tag.get_text(strip=True)
    elif tag.name == 'tbody':
        for tr in tag.find_all('tr'):
            cells = tr.find_all('td')
            row_data = {}

            if len(cells) > 0:
                try:
                    row_data['taxon'] = cells[0].find('i').get_text(strip=True)
                except:
                    try:
                        row_data['taxon'] = cells[0].get_text(strip=True)
                    except:
                        row_data['taxon'] = None


                try:
                    row_data['named_by'] = cells[0].find('small').get_text(strip=True)
                except:
                    try:
                        row_data['named_by'] = cells[0].find('span').get_text(strip=True)
                    except:
                        row_data['named_by'] = cells[0].get_text(strip=True)
            else:
                row_data['taxon'] = None
                row_data['named_by'] = None


            if len(cells) > 1:
                row_data['type'] = cells[1].get_text(strip=True)
            else:
                row_data['type'] = None


            if len(cells) > 2:
                row_data['namesake'] = cells[2].get_text(strip=True)
            else:
                row_data['namesake'] = None


            if len(cells) > 3:
                row_data['notes'] = cells[3].get_text(strip=True)
            else:
                row_data['notes'] = None


            row_data['media_type'] = current_h2
            row_data['fictional_universe'] = current_h3

            rows.append(row_data)
            print(f"Scraped: {row_data['taxon']}")

print(len(rows))
# Out:
# Scraped: None
# Scraped: Antigone antigone
# Scraped: Saguinus oedipus
# Scraped: Pseudoeurycea rex
# Scraped: Oedipodrilus oedipus
# Scraped: Amblytylus peitho
# Scraped: Atomophora astraia
# Scraped: Pseudotanais gaiae
# Scraped: Pseudotanais uranos
# Scraped: Phyllodrepa daedali
# Scraped: Phyllodrepa icari
# Scraped: Hotwheels sisyphus
# Scraped: None
# Scraped: Lokiceratops
# Scraped: Medusaceratops lokii
# Scraped: Joermungandr bolti
# Scraped: Jormungandr walhallaensis
# Scraped: Voconia loki
# Scraped: None
# Scraped: Gigantactis gargantua
# Scraped: Gargantuavis
# Scraped: Notoetayoa gargantuai
# Scraped: Epimeria gargantua
# Scraped: None
# Scraped: Wukongopterus
# Scraped: Ectatosticta wukong
# Scraped: Ectatosticta xuanzang
# Scraped: Ectatosticta bajie
# Scraped: Ectatosticta dapeng
# Scraped: Ectatosticta rulai
# Scraped: Syntelia sunwukong
# Scraped: Salassa sunwukongi
# Scraped: Brevistoma raksasiae
# Scraped: Ambulyx wukong
# Scraped: None
# Scraped: Oberonia
# Scraped: Sycorax
# Scraped: Peneothello
# Scraped: Pigrogromitus
# Scraped: Queubus
# Scraped: Iago
# Scraped: Geocharidius romeoi
# Scraped: Agra othello
# Scraped: Perdita desdemona
# Scraped: Perdita hippolyta
# Scraped: Perdita sycorax
# Scraped: Perdita titania
# Scraped: Alfaites romeo
# Scraped: Pseudotanais julietae
# Scraped: Pseudotanais romeo
# Scraped: Synagelides rosalindae
# Scraped: Synagelides orlandoi
# Scraped: None
# Scraped: Hipparion rocinantis
# Scraped: Dulcineaia manchegana
# Scraped: Ardistomis quixotei
# Scraped: Lohuecotitan pandafilandi
# Scraped: Carex quixotiana
# Scraped: None
# Scraped: Robinsonia
# Scraped: Hemistomia fridayi
# Scraped: Oncopagurus crusoei
# Scraped: None
# Scraped: Salticus lilliputanus
# Scraped: Holorusia brobdingnagia
# Scraped: Laputa
# Scraped: Paracardiophorus liliputanus
# Scraped: Blossfeldia liliputana
# Scraped: Balnibarbi
# Scraped: Dryadella lilliputiana
# Scraped: Blefuscuiana
# Scraped: Lilliputianella
# Scraped: Laputavis
# Scraped: Chorebus liliputanus
# Scraped: Viola lilliputana
# Scraped: Peruphorticus gulliveri
# Scraped: Meoneura lilliputensis
# Scraped: Anthobium liliputense
# Scraped: Pluteus liliputianus
# Scraped: Hypothenemus liliputianus
# Scraped: Matelea lilliputiana
# Scraped: None
# Scraped: Paracalanus quasimodo
# Scraped: Stylaclista quasimodo
# Scraped: Tetragnatha quasimodo
# Scraped: Agra eponine
# Scraped: Schistura quasimodo
# Scraped: Paradynomene quasimodo
# Scraped: Pseudione quasimodo
# Scraped: Neopantopsalis quasimodo
# Scraped: Harpirhynchus quasimodo
# Scraped: Quasimodorogas
# Scraped: Apseudes quasimodo
# Scraped: Selenoribates quasimodo
# Scraped: Chaleponcus quasimodo
# Scraped: Ephemeroporus quasimodo
# Scraped: Temnothorax quasimodo
# Scraped: Squalus quasimodo
# Scraped: Epimeria quasimodo
# Scraped: Haplochromis quasimodo
# Scraped: Mecolaesthus quasimodo
# Scraped: None
# Scraped: Schistura aramis
# Scraped: Schistura athos
# Scraped: Schistura porthos
# Scraped: None
# Scraped: Daggoo
# Scraped: Queequeg
# Scraped: Tashtego
# Scraped: Thaleops mobydicki
# Scraped: Voeltzkowia mobydick
# Scraped: Albicetus oxymycterus
# Scraped: Vrijenhoekia ahabi
# Scraped: None
# Scraped: Borogovia gracilicrus
# Scraped: Hemignathus vorpalis
# Scraped: None
# Scraped: Phanuromyia pauper
# Scraped: Phanuromyia princeps
# Scraped: None
# Scraped: Walckenaeria pinocchio
# Scraped: Masdevallia pinocchio
# Scraped: Oxypleurodon pinocchio
# Scraped: Pinocchiodinium
# Scraped: Platymamersopsis pinocchio
# Scraped: Uroptychus pinocchio
# Scraped: Eviota pinocchioi
# Scraped: Anchylorhynchus pinocchio
# Scraped: Monodelphis pinocchio
# Scraped: Pinocchia
# Scraped: Litoria pinocchio
# Scraped: Pinoquio
# Scraped: None
# Scraped: Irritator challengeri
# Scraped: Mandevilla sherlockii
# Scraped: None
# Scraped: Akela
# Scraped: Bagheera kiplingi
# Scraped: Messua
# Scraped: Nagaina
# Scraped: None
# Scraped: Garra cyrano
# Scraped: Eremobates cyranoi
# Scraped: Epimeria cyrano
# Scraped: None
# Scraped: Bradycneme draculae
# Scraped: Dracula vampira
# Scraped: Liparis draculoides
# Scraped: Desmodus draculae
# Scraped: Draculoides bramstokeri
# Scraped: Danionella dracula
# Scraped: Deinocroton draculi
# Scraped: Supraserphites draculi
# Scraped: Patrera dracula
# Scraped: Bensonella dracula
# Scraped: None
# Scraped: Tinkerbella nana
# Scraped: Ischnothyreus hooki
# Scraped: Meoneura tinkerbellae
# Scraped: None
# Scraped: Pimoa cthulhu
# Scraped: Millerocaulis tekelili
# Scraped: Nanocthulhu lovecrafti
# Scraped: Cthulhu macrofasciculumque
# Scraped: Cthylla microfasciculumque
# Scraped: Ochyrocera atlachnacha
# Scraped: Yogsothoth
# Scraped: Sollasina cthulhu
# Scraped: Fujuriphyes dagon
# Scraped: Fujuriphyes hydra
# Scraped: Fujuriphyes cthulhu
# Scraped: None
# Scraped: Eeyorius hutchinsi
# Scraped: Potamalpheops tigger
# Scraped: None
# Scraped: Ituglanis macunaima
# Scraped: Neotropiella macunaimae
# Scraped: Eucampesmella macunaima
# Scraped: None
# Scraped: Pseudolucia aureliana
# Scraped: Pseudolucia charlotte
# Scraped: Pseudolucia clarea
# Scraped: Pseudolucia hazeorum
# Scraped: Pseudolucia zembla
# Scraped: Itylos pnin
# Scraped: Madeleinea lolita
# Scraped: Madeleinea mashenka
# Scraped: Paralycaeides shade
# Scraped: Nabokovia ada
# Scraped: Madeleinea cobaltana
# Scraped: Madeleinea nodo
# Scraped: Madeleinea odon
# Scraped: Madeleinea tintarrona
# Scraped: Leptotes krug
# Scraped: Leptotes delalande
# Scraped: Pseudolucia humbert
# Scraped: Pseudolucia zina
# Scraped: Patalycaeides hazelea
# Scraped: Madeleinea ardisensis
# Scraped: Plebejus ardis
# Scraped: Plebejus pilgram
# Scraped: Plebejus pilgram
# Scraped: Plebejus fyodor
# Scraped: Humbert humberti
# Scraped: None
# Scraped: Cavisternum bom
# Scraped: Pelicinus tumpy
# Scraped: Pelicinus snooky
# Scraped: Ischnothyreus chippy
# Scraped: Silhouettella snippy
# Scraped: Silhouettella tiggy
# Scraped: None
# Scraped: Lasioseius gabrielae
# Scraped: Forcepsioneura gabriela
# Scraped: Eucampesmella pedrobala
# Scraped: Tietasaura
# Scraped: None
# Scraped: Synothele arrakis
# Scraped: Lycosa gesserit
# Scraped: Shaihuludia
# Scraped: Tulostoma shaihuludii
# Scraped: Arrakis
# Scraped: None
# Scraped: Ledermanniella maturiniana
# Scraped: Theognete maturini
# Scraped: None
# Scraped: Erechthias beeblebroxi
# Scraped: Bidenichthys beeblebroxi
# Scraped: Fiordichthys slartibartfasti
# Scraped: Babelichthys
# Scraped: None
# Scraped: Czekanowskia anguae
# Scraped: Ginkgoites weatherwaxiae
# Scraped: Ginkgoites nannyoggiae
# Scraped: Ginkgoites garlickianus
# Scraped: Phoenicopsis rincewindii
# Scraped: Pseudotorellia vimesiana
# Scraped: Sciadopityoides greeboana
# Scraped: Sulcatocladus dibbleri
# Scraped: Torreyites detriti
# Scraped: Apseudes atuini
# Scraped: Bathytanais greebo
# Scraped: Tanaella dongo
# Scraped: Aleiodes achingae
# Scraped: Aleiodes adorabelleae
# Scraped: Aleiodes anguaae
# Scraped: Aleiodes atuin
# Scraped: Aleiodes binkyi
# Scraped: Aleiodes conina
# Scraped: Aleiodes deathi
# Scraped: Aleiodes deyoyoi
# Scraped: Aleiodes downeyi
# Scraped: Aleiodes flannelfooti
# Scraped: Aleiodes gaspodei
# Scraped: Aleiodes herrena
# Scraped: Aleiodes lavaeolous
# Scraped: Aleiodes liessa
# Scraped: Aleiodes lipwigi
# Scraped: Aleiodes lipwigduplicitus
# Scraped: Aleiodes magratae
# Scraped: Aleiodes malichi
# Scraped: Aleiodes mericeti
# Scraped: Aleiodes morti
# Scraped: Aleiodes nivori
# Scraped: Aleiodes ponderi
# Scraped: Aleiodes prillae
# Scraped: Aleiodes pteppicymoni
# Scraped: Aleiodes ptraci
# Scraped: Aleiodes ridcullyi
# Scraped: Aleiodes rincewindi
# Scraped: Aleiodes sacharissa
# Scraped: Aleiodes selachiii
# Scraped: Aleiodes stibbonsi
# Scraped: Aleiodes stohelit
# Scraped: Aleiodes teatimei
# Scraped: Aleiodes tmaliaae
# Scraped: Aleiodes vetinarii
# Scraped: Periclimenes rincewindi
# Scraped: Dimophora rhysi
# Scraped: Pristomerus fourecksensis
# Scraped: None
# Scraped: Pseudotanais geralti
# Scraped: Pseudotanais yenneferae
# Scraped: None
# Scraped: Laelius arryni
# Scraped: Laelius baratheoni
# Scraped: Laelius lannisteri
# Scraped: Laelius martelli
# Scraped: Laelius targaryeni
# Scraped: Laelius tullyi
# Scraped: Laelius starki
# Scraped: Marianina khaleesi
# Scraped: Pheidole drogon
# Scraped: Pheidole viserion
# Scraped: Eadya daenerys
# Scraped: Ochyrocera varys
# Scraped: Paramonovius nightking
# Scraped: Abyssarya
# Scraped: Hodor hodor
# Scraped: Fujuriphyes viserioni
# Scraped: Gymnetis drogoni
# Scraped: Gymnetis rhaegali
# Scraped: Gymnetis viserioni
# Scraped: Targaryendraco
# Scraped: Meraxes
# Scraped: Baratheonus
# Scraped: Baratheonus roberti
# Scraped: Starkus
# Scraped: Lannisterella
# Scraped: Lannisterella cerseiae
# Scraped: None
# Scraped: Tetramorium rumo
# Scraped: Tetramorium rala
# Scraped: None
# Scraped: Strumigenys anorak
# Scraped: Strumigenys artemis
# Scraped: Strumigenys avatar
# Scraped: Strumigenys gunter
# Scraped: Strumigenys oasis
# Scraped: Strumigenys parzival
# Scraped: None
# Scraped: Skierka
# Scraped: Ophiodon ozymandias
# Scraped: Paramphientomum yumyum
# Scraped: Grendelius
# Scraped: Morlockia
# Scraped: Agra ichabod
# Scraped: Micropholcus evaluna
# Scraped: Boccacciomymar decameron
# Scraped: Candidatus
# Scraped: Trurlia
# Scraped: Calumma tarzan
# Scraped: Bokermannohyla sagarana
# Scraped: Aleiodes dresdeni
# Scraped: Auplopus charlesi
# Scraped: Dipogon marlowei
# Scraped: Priocnessus vancei
# Scraped: Inconnivus billibunteri
# Scraped: Oileus gasparilomi
# Scraped: Millerocaulis tekelili
# Scraped: Magelona sinbadi
# Scraped: Ophryotrocha langstrumpae
# Scraped: Calochaete cimrmanii
# Scraped: Goniomonas avonlea
# Scraped: Simlops jamesbondi
# Scraped: Chimerella corleone
# Scraped: Hyorhinomys stuempkei
# Scraped: Phytotelmatrichis osopaddington
# Scraped: Solanum watneyi
# Scraped: Aquilonifer spinosus
# Scraped: Fujuriphyes
# Scraped: Epimeria cinderella
# Scraped: Meoneura goldemari
# Scraped: Meoneura nilsholgerssoni
# Scraped: Meoneura oskari
# Scraped: Myrmecium oompaloompa
# Scraped: Ochyrocera charlotte
# Scraped: Ochyrocera misspider
# Scraped: Buratina truncata
# Scraped: Meoneura mucki
# Scraped: Mischocyttarus kallindusfloren
# Scraped: Tegenaria shirin
# Scraped: Caridina shahrazadae
# Scraped: Frenopyxis stierlitzi
# Scraped: Coptoborus katniss
# Scraped: Pseudotanais rapunzelae
# Scraped: Gallirallus astolfoi
# Scraped: Eucampesmella brascubas
# Scraped: Eucampesmella capitu
# Scraped: Eucampesmella iracema
# Scraped: Caramuruacarus
# Scraped: Helicina marfisae
# Scraped: Axoniderma wanda
# Scraped: Peltocephalus maturin
# Scraped: None
# Scraped: Scelio dupondi
# Scraped: Scelio janseni
# Scraped: Chaleponcus tintin
# Scraped: Neralsia haddocki
# Scraped: Xyalophora tintini
# Scraped: None
# Scraped: Teruzzicheles popeyei
# Scraped: Campsicnemus popeye
# Scraped: Cephennodes popeye
# Scraped: Masona popeye
# Scraped: Spelaeochernes popeye
# Scraped: Aenictus popeyei
# Scraped: None
# Scraped: Otocinclus batmani
# Scraped: Euragallia batmani
# Scraped: Kalelia
# Scraped: Trissolcus nycteridaner
# Scraped: Anthracites furvuseques
# Scraped: Biconcavus batmani
# Scraped: Kariridraco dianae
# Scraped: Agamopus joker
# Scraped: Epicratinus arlequina
# Scraped: None
# Scraped: Ogdoconta satana
# Scraped: Allodaposuchus hulki
# Scraped: Bromeloecia wolverinei
# Scraped: Otiothops doctorstrange
# Scraped: Thanos simonattoi
# Scraped: Cirrhilabrus wakanda
# Scraped: Discothyrea wakanda
# Scraped: Miroculis wolverine
# Scraped: Daptolestes bronteflavus
# Scraped: Daptolestes illusiolautus
# Scraped: Daptolestes feminategus
# Scraped: Humorolethalis
# Scraped: Habeastrum strangei
# Scraped: Gekko hulk
# Scraped: Voconia loki
# Scraped: Venomius
# Scraped: Urostephanus lokii
# Scraped: None
# Scraped: Lepidopa luciae
# Scraped: Mexicope sushara
# Scraped: Ceratocorema woodstocki
# Scraped: None
# Scraped: Agra smurf
# Scraped: Barrufeta
# Scraped: Carditella pitufina
# Scraped: None
# Scraped: Stichoplastoris asterix
# Scraped: Stichoplastoris obelix
# Scraped: Abraracourcix
# Scraped: Ordralfabetix
# Scraped: Nemesia asterix
# Scraped: Bela falbalae
# Scraped: Ondina asterixi
# Scraped: Payraudeautia obelixi
# Scraped: Trigonopterus asterix
# Scraped: Trigonopterus idefix
# Scraped: Trigonopterus obelix
# Scraped: Kochosa asterix
# Scraped: Kochosa obelix
# Scraped: None
# Scraped: Ochyrocera dorinha
# Scraped: Ochyrocera magali
# Scraped: Ochyrocera monica
# Scraped: Ochyrocera rosinha
# Scraped: None
# Scraped: Zagrammosoma hobbesi
# Scraped: Zagrammosoma calvini
# Scraped: None
# Scraped: Neostygarctus lovedeluxe
# Scraped: Funny valentine
# Scraped: Gyro zeppeli
# Scraped: Troglocoelotes doul
# Scraped: None
# Scraped: Ninjemys oweni
# Scraped: Sporopodiopsis mortimeriana
# Scraped: Hypocaccus kidpaddlei
# Scraped: Lurchibates
# Scraped: Euathlus condorito
# Scraped: Taito kakera
# Scraped: Nausicaamantis miyazakii
# Scraped: Meoneura joedaltoni
# Scraped: Cigaritis syama lamuae
# Scraped: Luthela kagami
# Scraped: Apseudes ranma
# Scraped: None
# Scraped: Ceraeochrysa michaelmuris
# Scraped: Celmus michaelmus
# Scraped: Bambiraptor feinbergi
# Scraped: Adelopsis dumbo
# Scraped: Corinna zecarioca
# Scraped: Endodrelanva jimini
# Scraped: Siphopteron dumbo
# Scraped: Helobdella buzz
# Scraped: Trichonympha hueyi
# Scraped: Trichonympha deweyi
# Scraped: Trichonympha louiei
# Scraped: Trichonympha webbyae
# Scraped: Epicratinus stitch
# Scraped: Maratus nemo
# Scraped: None
# Scraped: Strotarchus beepbeep
# Scraped: Cremnops wyleycoyotius
# Scraped: None
# Scraped: Erwiniana rosebudae
# Scraped: Orsonwelles ambersonorum
# Scraped: Orsonwelles arcanus
# Scraped: Orsonwelles calx
# Scraped: Orsonwelles falstaffius
# Scraped: Orsonwelles iudicium
# Scraped: Orsonwelles macbeth
# Scraped: Orsonwelles malus
# Scraped: Orsonwelles othello
# Scraped: Orsonwelles polites
# Scraped: Orsonwelles ventus
# Scraped: None
# Scraped: GodzilliidaeSchram, Yager & Emerson, 1986
# Scraped: Godzillius
# Scraped: Godzillognomus
# Scraped: Pleomothra
# Scraped: Gojirasaurus
# Scraped: Diplacodon gigan
# Scraped: Angirasu
# Scraped: et al
# Scraped: Kumonga
# Scraped: et al
# Scraped: Amblyrhynchus cristatus godzilla
# Scraped: Mecodema godzilla
# Scraped: Microgaster godzilla
# Scraped: Scytodes kumonga
# Scraped: Agroeca angirasu
# Scraped: Ramisyllis kingghidorahi
# Scraped: Mutotylaspis
# Scraped: Mosura
# Scraped: None
# Scraped: Xenomorphia
# Scraped: Dolichogenidea xenomorph
# Scraped: Coptoborus newt
# Scraped: Coptoborus ripley
# Scraped: Coptoborus vasquez
# Scraped: Bernardia xenomorpha
# Scraped: None
# Scraped: Hortipes terminator
# Scraped: Coptoborus sarahconnor
# Scraped: None
# Scraped: Pristomerus dundeei
# Scraped: Qrocodiledundee outbackense
# Scraped: None
# Scraped: Predatoroonops
# Scraped: Predatoroonops anna
# Scraped: Predatoroonops billy
# Scraped: Predatoroonops blain
# Scraped: Predatoroonops chicano
# Scraped: Predatoroonops dillon
# Scraped: Predatoroonops dutch
# Scraped: Predatoroonops maceliot
# Scraped: Predatoroonops olddemon
# Scraped: Predatoroonops phillips
# Scraped: Predatoroonops poncho
# Scraped: Predatoroonops rickhawkins
# Scraped: Predatoroonops vallarta
# Scraped: Predatoroonops valverde
# Scraped: Predatoroonops yautja
# Scraped: None
# Scraped: Agra lilu
# Scraped: Hirudicryptus quintumelementum
# Scraped: Coptoborus leeloo
# Scraped: None
# Scraped: Anelosimus biglebowski
# Scraped: Anelosimus dude
# Scraped: None
# Scraped: Oecobius kowalskii
# Scraped: Paroecobius skipper
# Scraped: Paroecobius rico
# Scraped: Paroecobius private
# Scraped: None
# Scraped: Ikrandraco avatar
# Scraped: Arctesthes avatar
# Scraped: Oligomonoctenus neytiriae
# Scraped: Avatar
# Scraped: Torukjara
# Scraped: None
# Scraped: Chloridops regiskongi
# Scraped: Eubetia boop
# Scraped: Ozraptor subotaii
# Scraped: Sinemys gamera
# Scraped: Shrekin
# Scraped: Teratohyla amelie
# Scraped: Tithaeus drac
# Scraped: Gamerabaena
# Scraped: Eoperipatus totoro
# Scraped: Cystomastacoides kiddo
# Scraped: Axima sidi
# Scraped: Prochyliza georgekaplani
# Scraped: Nosferatu
# Scraped: Zuul crurivastator
# Scraped: Prolatcyclus kindzadza
# Scraped: Coptoborus brigman
# Scraped: Coptoborus furiosa
# Scraped: Coptoborus trinity
# Scraped: Coptoborus vrataski
# Scraped: Trigonopterus gundala
# Scraped: Anisotremus rambo
# Scraped: Proctoporus optimus
# Scraped: Paravima totoro
# Scraped: Branchiostegus sanae
# Scraped: None
# Scraped: Yochelcionella daleki
# Scraped: Mestoronema
# Scraped: Tetramorium dalek
# Scraped: Synchiropus sycorax
# Scraped: Cyclocardia dalek
# Scraped: Choeras zygon
# Scraped: Ophiotardis
# Scraped: Dalek nationi
# Scraped: None
# Scraped: Conus tribblei
# Scraped: Agra dax
# Scraped: Boeckaspis geordii
# Scraped: Annuntidiogenes worfi
# Scraped: Paridris gorn
# Scraped: Ledella spocki
# Scraped: Bolianus
# Scraped: Synopeas klingunculum
# Scraped: Phanuromyia odo
# Scraped: Spockia
# Scraped: Coptoborus hansen
# Scraped: Coptoborus janeway
# Scraped: Coptoborus uhura
# Scraped: Coptoborus yar
# Scraped: Roddenberryus kirk
# Scraped: Roddenberryus mccoy
# Scraped: Roddenberryus spock
# Scraped: Boophis kirki
# Scraped: Boophis picardi
# Scraped: Boophis siskoi
# Scraped: Boophis janewayae
# Scraped: Boophis archeri
# Scraped: Boophis pikei
# Scraped: Boophis burnhamae
# Scraped: Agroecotettix idic
# Scraped: None
# Scraped: Geragnostus waldorfstatleri
# Scraped: Parabradya samsoni
# Scraped: Stelis oscargrouchii
# Scraped: Hensonbatrachus kermiti
# Scraped: Ariadna gonzo
# Scraped: Kermitops
# Scraped: None
# Scraped: Regalana bobbyi
# Scraped: Regalana dianae
# Scraped: Regalana ericki
# Scraped: Regalana hanki
# Scraped: Regalana prestoi
# Scraped: Alpaida venger
# Scraped: None
# Scraped: Spongiforma squarepantsii
# Scraped: Hemirhamphiculus krabsi
# Scraped: Astrolirus patricki
# Scraped: Xizangiana plankton
# Scraped: None
# Scraped: Eucteniza caprica
# Scraped: Coptoborus starbuck
# Scraped: None
# Scraped: Euglossa bazinga
# Scraped: Bazinga
# Scraped: Kalcerrytus leonardi
# Scraped: None
# Scraped: Spiralix heisenbergi
# Scraped: Hemipeplus heisenbergi
# Scraped: Hemipeplus saymyname
# Scraped: None
# Scraped: Savignia naniplopi
# Scraped: Alphomelon simpsonorum
# Scraped: Acmopolynema isaura
# Scraped: Boccacciomymar (Prosto) maria
# Scraped: Yochelcionella snorkorum
# Scraped: Odontacolus zimi
# Scraped: Lycocerus evangelium
# Scraped: Elthusa xena
# Scraped: Prosopanche demogorgoni
# Scraped: Salticus lucasi
# Scraped: Ahaetulla farnsworthi
# Scraped: Coptoborus scully
# Scraped: Trigonopterus unyil
# Scraped: Luthela asuka
# Scraped: None
# Scraped: Galagadon nordquistae
# Scraped: Taito galaga
# Scraped: None
# Scraped: Rotundicardia mariobrosorum
# Scraped: Maraenobiotus supermario
# Scraped: None
# Scraped: Epicratinus zelda
# Scraped: Lanayrella
# Scraped: Orcevia yahaha
# Scraped: Orcevia bokoblin
# Scraped: None
# Scraped: Epicratinus ehonda
# Scraped: Epicratinus zangief
# Scraped: None
# Scraped: Stentorceps weedlei
# Scraped: Aerodactylus
# Scraped: Chilicola charizard
# Scraped: Bulbasaurus phylloxyron
# Scraped: Dicranocentrus pikachu
# Scraped: Parapharyngodon politoedi
# Scraped: Binburrum articuno
# Scraped: Binburrum zapdos
# Scraped: Binburrum moltres
# Scraped: Epicratinus pikachu
# Scraped: Rathalos treecko
# Scraped: Anyphaena grovyle
# Scraped: Anyphaena sceptile
# Scraped: Alistra pikachu
# Scraped: Hiperantha pikachu
# Scraped: Nocticola pheromosa
# Scraped: Phrynarachne dreepy
# Scraped: None
# Scraped: Rapturella ryani
# Scraped: Rapturella atlas
# Scraped: None
# Scraped: Cortana
# Scraped: Crash bandicoot
# Scraped: Halystina umberlee
# Scraped: Taito spaceinvaders
# Scraped: Lagiacrusichthys
# Scraped: Neobuthus factorio
# Scraped: Demyrsus digmon
# Scraped: Epicratinus mauru
# Scraped: Epicratinus omegarugal
# Scraped: Euconnus hosakae
# Scraped: Emphysemastix frampt
# Scraped: Abaddon despoliator
# Scraped: Gothus teemo
# Scraped: Otacilia khezu
# Scraped: Epicratinus baraka
# Scraped: Epicratinus raiden
# Scraped: None
# Scraped: Hotwheels sisyphus
# Scraped: Orsonwelles bellum
# Scraped: Bacteriophage DjungelskogOliveros et al., 2024
# 719

# %%
df = pd.json_normalize(rows)
df
# Out:
#                                               taxon  \
# 0                                              None
# 1                                 Antigone antigone
# 2                                  Saguinus oedipus
# 3                                 Pseudoeurycea rex
# 4                              Oedipodrilus oedipus
# ..                                              ...
# 714                              Epicratinus raiden
# 715                                            None
# 716                              Hotwheels sisyphus
# 717                              Orsonwelles bellum
# 718  Bacteriophage DjungelskogOliveros et al., 2024
#
#                         named_by              type  \
# 0                           None              None
# 1               (Linnaeus, 1758)             Crane
# 2               (Linnaeus, 1758)  New World monkey
# 3                   (Dunn, 1921)        Salamander
# 4                     Holt, 1967    Segmented worm
# ..                           ...               ...
# 714  Gonçalves & Brescovit, 2024            Spider
# 715                         None              None
# 716            Liu & Zhang, 2024            Spider
# 717                Hormiga, 2002            Spider
# 718        Oliveros et al., 2024     Bacteriophage
#
#                                     namesake  \
# 0                                       None
# 1                           Antigone of Troy
# 2                                Oedipus Rex
# 3                                Oedipus Rex
# 4                                Oedipus Rex
# ..                                       ...
# 714                     Raiden,Mortal Kombat
# 715                                     None
# 716                               Hot Wheels
# 717  The War of the Worlds(1938 radio drama)
# 718                              Djungelskog
#
#                                                  notes   media_type  \
# 0                                                 None   Literature
# 1    The species was named after "Antigone, daughte...   Literature
# 2    "Linnaeus had a penchant for giving primates n...   Literature
# 3                    Species formerly namedOedipus rex   Literature
# 4                                                        Literature
# ..                                                 ...          ...
# 714  "Raiden is of "truth and light" and protector ...        Games
# 715                                               None  Other media
# 716  "The generic name refers to Hot Wheels, a coll...  Other media
# 717  "This species, collected below the radio tower...  Other media
# 718  "SharkoochyBord was rejected as a name, so we ...  Other media
#
#     fictional_universe
# 0      Greek mythology
# 1      Greek mythology
# 2      Greek mythology
# 3      Greek mythology
# 4      Greek mythology
# ..                 ...
# 714        Other games
# 715               None
# 716               None
# 717               None
# 718               None
#
# [719 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# taxon                  75
# named_by               75
# type                   77
# namesake               77
# notes                 112
# media_type              0
# fictional_universe      4
# dtype: int64

# %%
df.to_csv("species_fiction.csv")

# %% [markdown]
# The above list does not contain species named after Harry Potter, LOTR or Star Wars. These are separate Wiki pages with their own tables.
# # Scraping list of species named after characters from Harry Potter

# %%
response_HP = requests.get("https://en.wikipedia.org/wiki/List_of_organisms_named_after_the_Harry_Potter_series")
doc_HP = BeautifulSoup(response_HP.text, 'html.parser')

# %%
rows_HP = []
h2_HP = None

for tag in doc_HP.find_all(['h2', 'tbody']):
    if tag.name == 'h2':
        h2_HP = tag.get_text(strip=True)
        if h2_HP.lower() in ['references', 'see also', 'external links']:
            break  
    elif tag.name == 'tbody':
        for tr in tag.find_all('tr'):
            cells = tr.find_all('td')
            row_HP = {}
            try:
                row_HP['taxon'] = cells[0].find('a').get_text()
            except:
                row_HP['taxon'] = None
            try:
                row_HP['named_by'] = cells[0].find('span').get_text()
            except:
                row_HP['named_by'] = None
            try:
                row_HP['type'] = cells[1].find('a').get_text()
            except:
                row_HP['type'] = None
            try:
                row_HP['namesake'] = cells[2].find('a').get_text()
            except:
                row_HP['namesake'] = None
            try:
                row_HP['notes'] = cells[3].get_text(strip=True)
            except:
                row_HP['notes'] = None

            # Attach h2
            row_HP['character_type'] = h2_HP

            rows_HP.append(row_HP)
            
len(rows_HP)
# Out:
# 24

# %%
df_HP = pd.json_normalize(rows_HP)
df_HP.tail(15)
# Out:
#                        taxon                                  named_by  \
# 9               Aname aragog                        Harvey et al, 2012
# 10          Ampulex dementor                                 Ohl, 2014
# 11                Cis occamy       Rosa-Oliveira & Lopes-Andrade, 2023
# 12                  Thestral                     Faúndez & Rider, 2014
# 13        Leiocanthus nagini                      Sørensen et al, 2016
# 14                  Graphorn          Faúndez, Rider, & Carvajal, 2017
# 15            Lycosa aragogi                    Nadolny & Zamani, 2017
# 16      Attacobius demiguise  Pereira-Filho, Saturnino & Bonaldo, 2018
# 17       Ochyrocera aragogue         Brescovit, Cizauskas & Mota, 2018
# 18       Macrobiotus naginae                       Vecchi et al., 2022
# 19                      None                                      None
# 20     Macrocarpaea apparata                       J.R. Grant & Struwe
# 21  Clevosaurus sectumsemper                           Bonaparte, 2015
# 22       Dracorex hogwartsia                       Bakker et al., 2006
# 23        Metallactus bezoar                               Sassi, 2018
#
#                          type            namesake  \
# 9             Trapdoor spider              Aragog
# 10             Cockroach wasp            Dementor
# 11  Minute tree-fungus beetle              Occamy
# 12                  Stink bug            Thestral
# 13                 Kinorhynch              Nagini
# 14                  Stink bug            Graphorn
# 15                Wolf spider              Aragog
# 16        Corinnid sac spider           Demiguise
# 17                     Spider              Aragog
# 18                 Tardigrade              Nagini
# 19                       None                None
# 20               Gentianaceae          Apparating
# 21           Rhynchocephalian  Sectumsempra curse
# 22               Ornithischia            Hogwarts
# 23                Leaf beetle              Bezoar
#
#                                                 notes  \
# 9   "This species is named for J. K. Rowling’s fic...
# 10  "The new species is named after the 'dementors...
# 11  "The species name is inspired by the animal Oc...
# 12  "The ivory carinae and calluses on the dorsum ...
# 13  "The species name,nagini, is the female versio...
# 14  "Graphorn [...] from the fictional creature cr...
# 15  "This species is named after Aragog, the famou...
# 16  "The Demiguise is described in the Magizoology...
# 17  "The specific name refers to Aragog, a spider ...
# 18  "Named after J. K. Rowling’s Harry Potter book...
# 19                                               None
# 20  "The term describes the magical ability to van...
# 21  "Latin meaning ‘always cut’, an allusion to th...
# 22  "After the fictional 'Hogwarts Academy," inven...
# 23  "A bezoar is an object believed to have the po...
#
#                                 character_type
# 9                Named after magical creatures
# 10               Named after magical creatures
# 11               Named after magical creatures
# 12               Named after magical creatures
# 13               Named after magical creatures
# 14               Named after magical creatures
# 15               Named after magical creatures
# 16               Named after magical creatures
# 17               Named after magical creatures
# 18               Named after magical creatures
# 19  Named after spells, objects, and locations
# 20  Named after spells, objects, and locations
# 21  Named after spells, objects, and locations
# 22  Named after spells, objects, and locations
# 23  Named after spells, objects, and locations

# %%
df_HP['media_type'] = 'Literature'
df_HP['fictional_universe'] = 'Harry Potter'

# %%
df_HP
# Out:
#                        taxon                                    named_by  \
# 0                       None                                        None
# 1      Eriovixia gryffindori               Ahmed, Khalap & Sumukha, 2016
# 2          Harryplax severus                          Mendoza & Ng, 2017
# 3             Lusius malfoyi                        Saunders & Ward 2017
# 4       Leptanilla voldemort                                        None
# 5          Cardiomya minerva  Carvalho de Lima, Oliveira & Absalão, 2020
# 6              Alastor moody                                 Selis, 2020
# 7       Trimeresurus salazar                          Mirza et al., 2020
# 8                       None                                        None
# 9               Aname aragog                          Harvey et al, 2012
# 10          Ampulex dementor                                   Ohl, 2014
# 11                Cis occamy         Rosa-Oliveira & Lopes-Andrade, 2023
# 12                  Thestral                       Faúndez & Rider, 2014
# 13        Leiocanthus nagini                        Sørensen et al, 2016
# 14                  Graphorn            Faúndez, Rider, & Carvajal, 2017
# 15            Lycosa aragogi                      Nadolny & Zamani, 2017
# 16      Attacobius demiguise    Pereira-Filho, Saturnino & Bonaldo, 2018
# 17       Ochyrocera aragogue           Brescovit, Cizauskas & Mota, 2018
# 18       Macrobiotus naginae                         Vecchi et al., 2022
# 19                      None                                        None
# 20     Macrocarpaea apparata                         J.R. Grant & Struwe
# 21  Clevosaurus sectumsemper                             Bonaparte, 2015
# 22       Dracorex hogwartsia                         Bakker et al., 2006
# 23        Metallactus bezoar                                 Sassi, 2018
#
#                          type            namesake  \
# 0                        None                None
# 1           Orb-weaver spider   Godric Gryffindor
# 2            Pseudozioid crab        Harry Potter
# 3                        Wasp       Lucius Malfoy
# 4                         Ant      Lord Voldemort
# 5                     Bivalve  Minerva McGonagall
# 6                 Potter wasp       Alastor Moody
# 7                   Pit viper   Salazar Slytherin
# 8                        None                None
# 9             Trapdoor spider              Aragog
# 10             Cockroach wasp            Dementor
# 11  Minute tree-fungus beetle              Occamy
# 12                  Stink bug            Thestral
# 13                 Kinorhynch              Nagini
# 14                  Stink bug            Graphorn
# 15                Wolf spider              Aragog
# 16        Corinnid sac spider           Demiguise
# 17                     Spider              Aragog
# 18                 Tardigrade              Nagini
# 19                       None                None
# 20               Gentianaceae          Apparating
# 21           Rhynchocephalian  Sectumsempra curse
# 22               Ornithischia            Hogwarts
# 23                Leaf beetle              Bezoar
#
#                                                 notes  \
# 0                                                None
# 1   "This uniquely shaped spider derives its name ...
# 2   "The new genus is named primarily in honor of ...
# 3   "This species is named after Lucius Malfoy, a ...
# 4   "The fearsome antagonists in Harry Potter and ...
# 5   "This species is named after the character Min...
# 6   "The name  of this species is dedicated to the...
# 7   "The specific epithet is a noun in apposition ...
# 8                                                None
# 9   "This species is named for J. K. Rowling’s fic...
# 10  "The new species is named after the 'dementors...
# 11  "The species name is inspired by the animal Oc...
# 12  "The ivory carinae and calluses on the dorsum ...
# 13  "The species name,nagini, is the female versio...
# 14  "Graphorn [...] from the fictional creature cr...
# 15  "This species is named after Aragog, the famou...
# 16  "The Demiguise is described in the Magizoology...
# 17  "The specific name refers to Aragog, a spider ...
# 18  "Named after J. K. Rowling’s Harry Potter book...
# 19                                               None
# 20  "The term describes the magical ability to van...
# 21  "Latin meaning ‘always cut’, an allusion to th...
# 22  "After the fictional 'Hogwarts Academy," inven...
# 23  "A bezoar is an object believed to have the po...
#
#                                 character_type  media_type fictional_universe
# 0                          Named after wizards  Literature       Harry Potter
# 1                          Named after wizards  Literature       Harry Potter
# 2                          Named after wizards  Literature       Harry Potter
# 3                          Named after wizards  Literature       Harry Potter
# 4                          Named after wizards  Literature       Harry Potter
# 5                          Named after wizards  Literature       Harry Potter
# 6                          Named after wizards  Literature       Harry Potter
# 7                          Named after wizards  Literature       Harry Potter
# 8                Named after magical creatures  Literature       Harry Potter
# 9                Named after magical creatures  Literature       Harry Potter
# 10               Named after magical creatures  Literature       Harry Potter
# 11               Named after magical creatures  Literature       Harry Potter
# 12               Named after magical creatures  Literature       Harry Potter
# 13               Named after magical creatures  Literature       Harry Potter
# 14               Named after magical creatures  Literature       Harry Potter
# 15               Named after magical creatures  Literature       Harry Potter
# 16               Named after magical creatures  Literature       Harry Potter
# 17               Named after magical creatures  Literature       Harry Potter
# 18               Named after magical creatures  Literature       Harry Potter
# 19  Named after spells, objects, and locations  Literature       Harry Potter
# 20  Named after spells, objects, and locations  Literature       Harry Potter
# 21  Named after spells, objects, and locations  Literature       Harry Potter
# 22  Named after spells, objects, and locations  Literature       Harry Potter
# 23  Named after spells, objects, and locations  Literature       Harry Potter

# %%
#Reading in species_fiction dataset 
species = pd.read_csv("species_fiction.csv")

# %%
# Adding HP dataset to species dataset
species = pd.concat([species, df_HP], ignore_index=True)

# %%
species.shape
# Out:
# (743, 9)

# %% [markdown]
# # Scraping list of species named after Tolkien and his works

# %%
response = requests.get("https://en.wikipedia.org/wiki/List_of_things_named_after_J._R._R._Tolkien_and_his_works")
doc_tolk = BeautifulSoup(response.text, 'html.parser')

# %%
rows_tolk = []
h3_tolk = None
h2_found = False

for tag in doc_tolk.find_all(['h2', 'h3', 'tbody']):
    if tag.name == 'h2':
        h2_text = tag.get_text(strip=True)
        if h2_text == 'Taxonomy':
            h2_found = True
        elif h2_found:
            break  

    elif h2_found and tag.name == 'h3':
        h3_tolk = tag.get_text(strip=True)

    elif h2_found and tag.name == 'tbody':
        for tr in tag.find_all('tr'):
            cells = tr.find_all('td')
            row_tolk = {}

            try:
                row_tolk['taxon'] = cells[0].find('i').get_text(strip=True)
            except:
                try:
                    row_tolk['taxon'] = cells[0].get_text(strip=True)
                except:
                    row_tolk['taxon'] = None

            try:
                row_tolk['named_by'] = cells[0].find('span').get_text(strip=True)
            except:
                row_tolk['named_by'] = None

            try:
                row_tolk['type'] = cells[1].get_text(strip=True)
            except:
                row_tolk['type'] = None

            try:
                row_tolk['namesake'] = cells[2].get_text(strip=True)
            except:
                row_tolk['namesake'] = None

            try:
                row_tolk['notes'] = cells[3].get_text(strip=True)
            except:
                row_tolk['notes'] = None

        
            row_tolk['character_type'] = h3_tolk
            row_tolk['fictional_universe'] = 'Tolkien'
            row_tolk['media_type'] = 'Literature'

            rows_tolk.append(row_tolk)

print(f"Scraped {len(rows_tolk)} Tolkien rows.")
# Out:
# Scraped 230 Tolkien rows.

# %%
df_tolk = pd.json_normalize(rows_tolk)
df_tolk.tail(15)
# Out:
#                       taxon                          named_by            type  \
# 215  Hyperlais orodruinella    Korb, Gorbunov & Melyakh, 2023            Moth
# 216                    None                              None            None
# 217         Aletodon mellon                   Van Valen, 1978   Fossil mammal
# 218     Chriacus calenancus                   Van Valen, 1978   Fossil mammal
# 219      Litomylus alphamon                    Van Valen 1978   Fossil mammal
# 220        Mimatuta minuial                   Van Valen, 1978   Fossil mammal
# 221    Thangorodrim thalion                   Van Valen, 1978   Fossil mammal
# 222      Elachista aranella                       Kaila, 1999            Moth
# 223         Helicops nentur                  Costaet al, 2016           Snake
# 224          Hylaeus mellon     Dathe and Proshchalykin, 2016             Bee
# 225       Epimeria anguloce            d’Acoz & Verheye, 2017        Amphipod
# 226         Thiodina perian           Bustamante & Ruiz, 2017  Jumping spider
# 227                  Vanima  Zacca, Casagrande & Mielke, 2020       Butterfly
# 228                    None                              None            None
# 229   Aspidoras psammatides       Britto, Lima & Santos, 2005         Catfish
#
#                              namesake  \
# 215              Orodruin(Mount Doom)
# 216                              None
# 217                            mellon
# 218                        calen,anca
# 219                         alph,amon
# 220                           minuial
# 221                           thalion
# 222                             aran-
# 223                           nen,tur
# 224                            mellon
# 225                          angulócë
# 226                            perian
# 227                            vanima
# 228                              None
# 229  Psamathos Psamathides,Roverandom
#
#                                                  notes         character_type  \
# 215  "We name the new species after Mount Orodruin....  Objects and locations
# 216                                               None           Elvish words
# 217  "Sindarin (Elvish) mellon, friend, the passwor...           Elvish words
# 218  "Sindarin (Elvish) calen, green; anca, Jaws. R...           Elvish words
# 219  "Sindarin (Elvish) alph, swan, and amon, hill....           Elvish words
# 220  "Sindarin (Elvish) minuial, the time at dawn w...           Elvish words
# 221  "Sindarin (Elvish) thalion, strong. Reference ...           Elvish words
# 222  "E. aranellaseems to owe its name toaran-, the...           Elvish words
# 223  "The namenenturis formed by the (Quenya) words...           Elvish words
# 224          "mellon (High Elvish [Sindarin]): friend"           Elvish words
# 225  "Angulócë, dragon — Tolkien’s Quenya language ...           Elvish words
# 226  "The specific name is a noun in apposition tak...           Elvish words
# 227            In Quenya (elvish)vanimameans beautiful           Elvish words
# 228                                               None            Other works
# 229  "Psammatides, after 'Psammatos psammatides'  [...            Other works
#
#     fictional_universe  media_type
# 215            Tolkien  Literature
# 216            Tolkien  Literature
# 217            Tolkien  Literature
# 218            Tolkien  Literature
# 219            Tolkien  Literature
# 220            Tolkien  Literature
# 221            Tolkien  Literature
# 222            Tolkien  Literature
# 223            Tolkien  Literature
# 224            Tolkien  Literature
# 225            Tolkien  Literature
# 226            Tolkien  Literature
# 227            Tolkien  Literature
# 228            Tolkien  Literature
# 229            Tolkien  Literature

# %%
# Adding Tolkien dataset to species dataset
species = pd.concat([species, df_tolk], ignore_index=True)

# %%
species.shape
# Out:
# (973, 9)

# %% [markdown]
# # Scraping list of species named after Star Wars

# %%
response = requests.get("https://en.wikipedia.org/wiki/List_of_organisms_named_after_the_Star_Wars_series")
doc_star = BeautifulSoup(response.text, 'html.parser')

# %%
doc_star.find('h1').text
# Out:
# 'List of organisms named after the Star Wars series'

# %%
rows_star = []
h2_star = None

for tag in doc_star.find_all(['h2', 'tbody']):
    if tag.name == 'h2':
        h2_star = tag.get_text(strip=True)
        if h2_star.lower() in ['references', 'see also', 'external links']:
            break

    elif tag.name == 'tbody':
        for tr in tag.find_all('tr'):
            cells = tr.find_all('td')
            row_star = {}

            
            try:
                row_star['taxon'] = cells[0].find('i').get_text(strip=True)
            except:
                try:
                    row_star['taxon'] = cells[0].find('a').get_text(strip=True)
                except:
                    try:
                        row_star['taxon'] = cells[0].get_text(strip=True)
                    except:
                        row_star['taxon'] = None

            
            try:
                row_star['named_by'] = cells[0].find('small').get_text(strip=True)
            except:
                try:
                    row_star['named_by'] = cells[0].find('span').get_text(strip=True)
                except:
                    row_star['named_by'] = None

            
            try:
                row_star['type'] = cells[1].get_text(strip=True)
            except:
                row_star['type'] = None

            
            try:
                row_star['namesake'] = cells[2].get_text(strip=True)
            except:
                row_star['namesake'] = None

            
            try:
                row_star['notes'] = cells[3].get_text(strip=True)
            except:
                row_star['notes'] = None

            
            row_star['character_type'] = h2_star
            row_star['fictional_universe'] = 'Star Wars'
            row_star['media_type'] = 'Films'

            rows_star.append(row_star)

print(f"Scraped {len(rows_star)} Star Wars entries.")
# Out:
# Scraped 74 Star Wars entries.

# %%
df_star = pd.json_normalize(rows_star)
df_star.head(15)
# Out:
#                         taxon                          named_by  \
# 0                        None                              None
# 1          Epicratinus anakin       Gonçalves & Brescovit, 2020
# 2           Epicratinus vader       Gonçalves & Brescovit, 2020
# 3           Polemistus vaderi             Menke & Vincent, 1983
# 4   Darthvaderum greensladeae                        Hunt, 1996
# 5          Adelomyrmex vaderi                   Fernández, 2003
# 6             Thricops vaderi                      Savage, 2003
# 7           Agathidium vaderi          Miller and Wheeler, 2005
# 8     Garthambrus darthvaderi             McLay & S.H.Tan, 2009
# 9    Zoosphaerium darthvaderi         Wesener & Bespalova, 2010
# 10     Begonia darthvaderiana                         Lin,et al
# 11         Diastolinus vaderi               Hart and Ivie, 2016
# 12  Lepidogryllus darthvaderi  Desutter-Grandcolas & Anso, 2016
# 13             Ricinus vaderi                       Valan, 2016
# 14        Vaderlimulus tricki                  Lerneret al.2017
#
#                type                                           namesake  \
# 0              None                                               None
# 1            Spider  "Anakin is a character which change[s] from th...
# 2            Spider  "Darth Vader is a character which wears a cost...
# 3              Wasp  Menke stated that he "wanted to add a little h...
# 4              Mite  "When I saw theSEMof the gnathosoma I immediat...
# 5               Ant  "The dark aspect of these ants evokes Darth Va...
# 6          True fly
# 7            Beetle  Darth Vader "shares withA. vaderia broad, shin...
# 8              Crab  The specific epithet "alludes to the helmet-li...
# 9         Millipede  "From theStar Warscharacter Darth Vader, whose...
# 10          Begonia  "The epithet refers to the resemblance of the ...
# 11  Darkling beetle  The species has a "shiny black head and pronot...
# 12          Cricket  "Species named after its striking coloration w...
# 13    Chewing louse  "The first author’s fiancée noticed a similari...
# 14   Horseshoe Crab
#
#        notes           character_type fictional_universe media_type
# 0       None  Named after Darth Vader          Star Wars      Films
# 1        [4]  Named after Darth Vader          Star Wars      Films
# 2       None  Named after Darth Vader          Star Wars      Films
# 3     [5][6]  Named after Darth Vader          Star Wars      Films
# 4        [7]  Named after Darth Vader          Star Wars      Films
# 5        [8]  Named after Darth Vader          Star Wars      Films
# 6        [9]  Named after Darth Vader          Star Wars      Films
# 7   [10][11]  Named after Darth Vader          Star Wars      Films
# 8       [12]  Named after Darth Vader          Star Wars      Films
# 9       [13]  Named after Darth Vader          Star Wars      Films
# 10      [14]  Named after Darth Vader          Star Wars      Films
# 11      [15]  Named after Darth Vader          Star Wars      Films
# 12      [16]  Named after Darth Vader          Star Wars      Films
# 13      [17]  Named after Darth Vader          Star Wars      Films
# 14      [18]  Named after Darth Vader          Star Wars      Films

# %%
# Adding Star Wars dataset to species dataset
species = pd.concat([species, df_star], ignore_index=True)

# %%
species.shape
# Out:
# (1047, 9)

# %%
species.to_csv("species_scraped.csv")

# %% [markdown]
# # Cleaning scraped data

# %%
species.head()
# Out:
#    Unnamed: 0                 taxon          named_by              type  \
# 0         0.0                   NaN               NaN               NaN
# 1         1.0     Antigone antigone  (Linnaeus, 1758)             Crane
# 2         2.0      Saguinus oedipus  (Linnaeus, 1758)  New World monkey
# 3         3.0     Pseudoeurycea rex      (Dunn, 1921)        Salamander
# 4         4.0  Oedipodrilus oedipus        Holt, 1967    Segmented worm
#
#            namesake                                              notes  \
# 0               NaN                                                NaN
# 1  Antigone of Troy  The species was named after "Antigone, daughte...
# 2       Oedipus Rex  "Linnaeus had a penchant for giving primates n...
# 3       Oedipus Rex                  Species formerly namedOedipus rex
# 4       Oedipus Rex                                                NaN
#
#    media_type fictional_universe character_type
# 0  Literature    Greek mythology            NaN
# 1  Literature    Greek mythology            NaN
# 2  Literature    Greek mythology            NaN
# 3  Literature    Greek mythology            NaN
# 4  Literature    Greek mythology            NaN

# %%
#Dropping unnamed column
species = species.drop(columns = ['Unnamed: 0'])

# %%
species
# Out:
#                             taxon  \
# 0                             NaN
# 1               Antigone antigone
# 2                Saguinus oedipus
# 3               Pseudoeurycea rex
# 4            Oedipodrilus oedipus
# ...                           ...
# 1042       Calponia harrisonfordi
# 1043       Pheidole harrisonfordi
# 1044  Tachymenoides harrisonfordi
# 1045      Cantharis mikkelsenorum
# 1046             Ctenus monaghani
#
#                                            named_by              type  \
# 0                                               NaN               NaN
# 1                                  (Linnaeus, 1758)             Crane
# 2                                  (Linnaeus, 1758)  New World monkey
# 3                                      (Dunn, 1921)        Salamander
# 4                                        Holt, 1967    Segmented worm
# ...                                             ...               ...
# 1042                                 Platnick, 1993            Spider
# 1043                             E. O. Wilson, 2002               Ant
# 1044  Lehr, Cusi, Fernandez, Vera & Catenazzi, 2023             Snake
# 1045                       Cantharis mikkelsenorum†            Beetle
# 1046                                    Jäger, 2013            Spider
#
#                              namesake  \
# 0                                 NaN
# 1                    Antigone of Troy
# 2                         Oedipus Rex
# 3                         Oedipus Rex
# 4                         Oedipus Rex
# ...                               ...
# 1042                    Harrison Ford
# 1043                    Harrison Ford
# 1044                    Harrison Ford
# 1045  Lars MikkelsenandMads Mikkelsen
# 1046                 Dominic Monaghan
#
#                                                   notes  media_type  \
# 0                                                   NaN  Literature
# 1     The species was named after "Antigone, daughte...  Literature
# 2     "Linnaeus had a penchant for giving primates n...  Literature
# 3                     Species formerly namedOedipus rex  Literature
# 4                                                   NaN  Literature
# ...                                                 ...         ...
# 1042  Named after Harrison Ford to thank him for nar...       Films
# 1043  Named after Harrison Ford in honor of his work...       Films
# 1044  "We dedicate this species to Harrison Ford, ac...       Films
# 1045  A fossilsoldier beetlefound inBaltic amberfrom...       Films
# 1046  Awandering spiderfromLaos, "named in honour of...       Films
#
#      fictional_universe              character_type
# 0       Greek mythology                         NaN
# 1       Greek mythology                         NaN
# 2       Greek mythology                         NaN
# 3       Greek mythology                         NaN
# 4       Greek mythology                         NaN
# ...                 ...                         ...
# 1042          Star Wars  Named afterStar Warsactors
# 1043          Star Wars  Named afterStar Warsactors
# 1044          Star Wars  Named afterStar Warsactors
# 1045          Star Wars  Named afterStar Warsactors
# 1046          Star Wars  Named afterStar Warsactors
#
# [1047 rows x 8 columns]

# %%
#Finding empty rows
print(species['taxon'].isna().value_counts())
# Out:
# taxon
# False    944
# True     103
# Name: count, dtype: int64

# %%
species[species['taxon'].isna()]
# Out:
#      taxon named_by  type namesake notes  media_type  \
# 0      NaN      NaN   NaN      NaN   NaN  Literature
# 12     NaN      NaN   NaN      NaN   NaN  Literature
# 18     NaN      NaN   NaN      NaN   NaN  Literature
# 23     NaN      NaN   NaN      NaN   NaN  Literature
# 34     NaN      NaN   NaN      NaN   NaN  Literature
# ...    ...      ...   ...      ...   ...         ...
# 1012  None     None  None     None  None       Films
# 1015  None     None  None     None  None       Films
# 1018  None     None  None     None  None       Films
# 1021  None     None  None     None  None       Films
# 1038  None     None  None     None  None       Films
#
#             fictional_universe                             character_type
# 0              Greek mythology                                        NaN
# 12             Norse mythology                                        NaN
# 18    Gargantua and Pantagruel                                        NaN
# 23         Journey to the West                                        NaN
# 34         William Shakespeare                                        NaN
# ...                        ...                                        ...
# 1012                 Star Wars                       Named after Han Solo
# 1015                 Star Wars                  Named after Padmé Amidala
# 1018                 Star Wars                          Named after Porgs
# 1021                 Star Wars  Named after other characters and elements
# 1038                 Star Wars                 Named afterStar Warsactors
#
# [103 rows x 8 columns]

# %%
#Dropping empty rows
species = species.dropna(subset=['taxon']).reset_index(drop=True)

# %%
species.shape
# Out:
# (944, 8)

# %%
#Extracting 'year' and name from 'named_by' column
import re

# %%
species["year"] = species["named_by"].str.extract(r"(\d{4})", expand=False)

# %%
species.head()
# Out:
#                   taxon          named_by              type          namesake  \
# 0     Antigone antigone  (Linnaeus, 1758)             Crane  Antigone of Troy
# 1      Saguinus oedipus  (Linnaeus, 1758)  New World monkey       Oedipus Rex
# 2     Pseudoeurycea rex      (Dunn, 1921)        Salamander       Oedipus Rex
# 3  Oedipodrilus oedipus        Holt, 1967    Segmented worm       Oedipus Rex
# 4     Amblytylus peitho  Linnavuori, 1997          Leaf bug            Peitho
#
#                                                notes  media_type  \
# 0  The species was named after "Antigone, daughte...  Literature
# 1  "Linnaeus had a penchant for giving primates n...  Literature
# 2                  Species formerly namedOedipus rex  Literature
# 3                                                NaN  Literature
# 4                                                NaN  Literature
#
#   fictional_universe character_type  year
# 0    Greek mythology            NaN  1758
# 1    Greek mythology            NaN  1758
# 2    Greek mythology            NaN  1921
# 3    Greek mythology            NaN  1967
# 4    Greek mythology            NaN  1997

# %%
species['named_by_clean'] = (species['named_by'].str.replace(r',?\s*\d{4}', '', regex=True).str.strip().str.strip('()'))

# %%
species.head()
# Out:
#                   taxon          named_by              type          namesake  \
# 0     Antigone antigone  (Linnaeus, 1758)             Crane  Antigone of Troy
# 1      Saguinus oedipus  (Linnaeus, 1758)  New World monkey       Oedipus Rex
# 2     Pseudoeurycea rex      (Dunn, 1921)        Salamander       Oedipus Rex
# 3  Oedipodrilus oedipus        Holt, 1967    Segmented worm       Oedipus Rex
# 4     Amblytylus peitho  Linnavuori, 1997          Leaf bug            Peitho
#
#                                                notes  media_type  \
# 0  The species was named after "Antigone, daughte...  Literature
# 1  "Linnaeus had a penchant for giving primates n...  Literature
# 2                  Species formerly namedOedipus rex  Literature
# 3                                                NaN  Literature
# 4                                                NaN  Literature
#
#   fictional_universe character_type  year named_by_clean
# 0    Greek mythology            NaN  1758       Linnaeus
# 1    Greek mythology            NaN  1758       Linnaeus
# 2    Greek mythology            NaN  1921           Dunn
# 3    Greek mythology            NaN  1967           Holt
# 4    Greek mythology            NaN  1997     Linnavuori

# %%
#Renaming some columns
species = species.rename(columns = {'named_by' : 'named_by_wiki', 'notes' : 'notes_wiki', 'year' : 'year_wiki', 'named_by_clean' : 'named_by_clean_wiki' })

# %%
#Reordering columns
species = species[['taxon', 'type', 'namesake', 'year_wiki', 'named_by_clean_wiki',
     'fictional_universe', 'character_type', 'media_type', 'notes_wiki', 'named_by_wiki']]

# %%
species.head()
# Out:
#                   taxon              type          namesake year_wiki  \
# 0     Antigone antigone             Crane  Antigone of Troy      1758
# 1      Saguinus oedipus  New World monkey       Oedipus Rex      1758
# 2     Pseudoeurycea rex        Salamander       Oedipus Rex      1921
# 3  Oedipodrilus oedipus    Segmented worm       Oedipus Rex      1967
# 4     Amblytylus peitho          Leaf bug            Peitho      1997
#
#   named_by_clean_wiki fictional_universe character_type  media_type  \
# 0            Linnaeus    Greek mythology            NaN  Literature
# 1            Linnaeus    Greek mythology            NaN  Literature
# 2                Dunn    Greek mythology            NaN  Literature
# 3                Holt    Greek mythology            NaN  Literature
# 4          Linnavuori    Greek mythology            NaN  Literature
#
#                                           notes_wiki     named_by_wiki
# 0  The species was named after "Antigone, daughte...  (Linnaeus, 1758)
# 1  "Linnaeus had a penchant for giving primates n...  (Linnaeus, 1758)
# 2                  Species formerly namedOedipus rex      (Dunn, 1921)
# 3                                                NaN        Holt, 1967
# 4                                                NaN  Linnavuori, 1997

# %%
species.shape
# Out:
# (944, 10)

# %%
species.to_csv("species_cleaned_wiki.csv", index = False)
